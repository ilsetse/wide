# %%
from finna_client import FinnaClient as fc
from finna_client import FinnaSearchType as fst 
import time 

tst1 = fc() 
lookfor = "EEG"

# %%
time1 = time.time() 
tst1_res = tst1.search(lookfor=lookfor,
                       search_type=fst.Subject,
                       fields=["buildings", "subjects"],
                       filters=["main_date_str:2017"],
                       page=1,
                       limit=100)
time2 = time.time() 
print("Time it took: {:6.4f}s".format(time2-time1))
# Out:
# Time it took: 0.1952s

# %%
def count_subjects(records):
    subject_count = {} 
    for record in records: 
        for subject in record['subjects']:
            subject = subject[0].lower() 
            try: 
                subject_count [subject] += 1 
            except KeyError: 
                subject_count [subject] = 1
    return subject_count
            
count_subjects(tst1_res['records'])
# Out:
# {'mietiskely': 1,
#  'tietoinen läsnäolo': 1,
#  'eeg': 18,
#  'sanat': 1,
#  'prosessointi': 1,
#  'merkitys': 1,
#  'organisaatiot': 1,
#  'herätevaste': 1,
#  'elektromyografia': 1,
#  'korrelaatio': 1,
#  'silmänliikkeet': 1,
#  'neuroverkot': 1,
#  'emd': 1,
#  'huippukorrelaatioanalyysi': 1,
#  'responses': 1,
#  'emotions': 1,
#  'neurons': 1,
#  'spectral linear discriminant analysis': 1,
#  'brain': 2,
#  'syke': 1,
#  'heart rate variability': 1,
#  'hrv': 1,
#  'cardiac cycle': 1,
#  'learning': 1,
#  'trace conditioning': 1,
#  'electroencephalography.': 2,
#  'magnetoencephalography.': 2,
#  'short-term memory.': 2,
#  'fysiologia ja neurotiede': 2,
#  'hermoverkko': 2,
#  'meg': 3,
#  'työmuisti': 2,
#  'masennus': 3,
#  'kasvontunnistus': 1,
#  'ilmeet': 3,
#  'tunteet': 1,
#  'tulkinta': 1,
#  'aivotutkimus': 3,
#  'neuropsykologia': 3,
#  'psykoterapia': 1,
#  'kognitiivinen terapia': 1,
#  'käyttäytymisterapia': 1,
#  'ryhmäterapia': 1,
#  'cbasp': 1,
#  'eye diseases': 1,
#  'facial expressions': 1,
#  'visuality': 1,
#  'recognition': 1,
#  'facial recognition': 1,
#  'age-related eye diseases': 1,
#  'bevacizumab': 1,
#  'face recognition': 1,
#  'n170': 1,
#  'ms-tauti': 2,
#  'potilaat': 2,
#  'kognitio': 2,
#  'kognitiiviset prosessit': 2,
#  'arviointi': 2,
#  'elämänlaatu': 2,
#  'heikentyminen': 2,
#  'uupumus': 2,
#  'neurofysiologia': 2,
#  'mittaus': 2,
#  'cnv': 2,
#  'p3': 2,
#  'cognition': 2,
#  'fatigue': 2,
#  'multiple sclerosis': 2,
#  'quality of life': 2,
#  'ikääntyneet': 1,
#  'kuvantaminen': 2,
#  'magneettitutkimus': 4,
#  'magnetoencephalography': 1,
#  'electroencephalography': 1,
#  'brain mapping': 1,
#  'brain diseases': 1,
#  'epilepsia': 2,
#  'hermoston taudit': 1,
#  'diagnostiikka': 2,
#  'oireet': 1,
#  'vilppula, anitta.': 1,
#  'röntgentutkimus': 1,
#  'ultraäänitutkimus': 1,
#  'tietokonetomografia': 1,
#  'liitännäistaudit': 1,
#  'uni': 1,
#  'hengitys': 1,
#  'häiriöt': 1,
#  'esiintyvyys': 1,
#  'tutkimus': 1,
#  'kyselytutkimus': 1,
#  'univaje': 1,
#  'väsymys': 1,
#  'uniapnea-oireyhtymä': 1,
#  'unihäiriöt': 1,
#  'äkkikuolema': 1,
#  'kuolleisuus': 1,
#  'hoitomenetelmät': 1,
#  'lääkehoito': 1,
#  'suomi': 1,
#  'unipolygrafia': 1,
#  'obstruktiivinen uniapnea': 1,
#  'cpap': 1,
#  'temporaaliepilepsia': 1,
#  'otsolohkoepilepsia': 1,
#  'robotit': 1,
#  'tekoäly': 1,
#  'uhkakuvat': 1,
#  'autonomiset järjestelmät': 1,
#  'keksinnöt': 1,
#  'innovaatiot': 1,
#  'ihminen-konejärjestelmät': 1,
#  'algoritmit': 1,
#  'robotiikka': 1,
#  'hakkerointi': 1,
#  'ihminen': 1,
#  'sotatekniikka': 1,
#  'manipulaatio': 1,
#  'telepatia': 1,
#  'kauko-ohjaus': 1,
#  'koneet': 1,
#  'muisti': 1,
#  'tietoturva': 1,
#  'teknologia': 1,
#  'ajatukset': 1}

# %%
tst1_res['records'][0]['buildings'][0]['translated']
# Out:
# 'Jyväskylän yliopisto'

# %%
a = { 'a': 1, 'b': 2}

try:
    a['c'] += 1 
except KeyError: 
    a['c'] = 1

a
# Out:
# {'a': 1, 'b': 2, 'c': 1}

# %%
'Short-term memory.'.lower()
# Out:
# 'short-term memory.'

# %%
result['records'][0]['subjects']
# Out:
# ['mietiskely', 'tietoinen läsnäolo', 'EEG']

# %%
fc().search(lookfor=lookfor,
                   search_type=fst.Subject,
                   fields=["buildings", "subjects"],
                   filters=["main_date_str:2017"],
                   page=1,
                   limit=100)
# Out:
# {'resultCount': 18,
#  'records': [{'buildings': [{'value': '0/JYU/',
#      'translated': 'Jyväskylän yliopisto'}],
#    'subjects': [['mietiskely'], ['tietoinen läsnäolo'], ['EEG']]},
#   {'buildings': [{'value': '0/TY/', 'translated': 'Turun yliopisto'},
#     {'value': '1/TY/100/', 'translated': 'Feeniks'}],
#    'subjects': [['EEG'],
#     ['sanat'],
#     ['prosessointi'],
#     ['merkitys'],
#     ['organisaatiot'],
#     ['herätevaste']]},
#   {'buildings': [{'value': '0/TY/', 'translated': 'Turun yliopisto'},
#     {'value': '1/TY/4000/', 'translated': 'Quantum'}],
#    'subjects': [['EEG'],
#     ['elektromyografia'],
#     ['korrelaatio'],
#     ['silmänliikkeet'],
#     ['neuroverkot'],
#     ['EMD'],
#     ['huippukorrelaatioanalyysi']]},
#   {'buildings': [{'value': '0/JYU/', 'translated': 'Jyväskylän yliopisto'}],
#    'subjects': [['responses'],
#     ['emotions'],
#     ['neurons'],
#     ['EEG'],
#     ['Spectral Linear Discriminant Analysis'],
#     ['brain']]},
#   {'buildings': [{'value': '0/JYU/', 'translated': 'Jyväskylän yliopisto'}],
#    'subjects': [['syke'],
#     ['EEG'],
#     ['heart rate variability'],
#     ['HRV'],
#     ['cardiac cycle'],
#     ['learning'],
#     ['trace conditioning']]},
#   {'buildings': [{'value': '0/helka/', 'translated': 'Helka-kirjastot'},
#     {'value': '1/helka/339/', 'translated': 'elektroniset kokoelmat'},
#     {'value': '2/helka/339/606/', 'translated': 'Viikin kampuskirjasto'}],
#    'subjects': [['Electroencephalography.'],
#     ['Magnetoencephalography.'],
#     ['Short-term memory.'],
#     ['EEG'],
#     ['fysiologia ja neurotiede'],
#     ['hermoverkko'],
#     ['MEG'],
#     ['työmuisti']]},
#   {'buildings': [{'value': '0/JYU/', 'translated': 'Jyväskylän yliopisto'}],
#    'subjects': [['masennus'],
#     ['kasvontunnistus'],
#     ['ilmeet'],
#     ['tunteet'],
#     ['tulkinta'],
#     ['aivotutkimus'],
#     ['EEG'],
#     ['neuropsykologia'],
#     ['psykoterapia'],
#     ['kognitiivinen terapia'],
#     ['käyttäytymisterapia'],
#     ['ryhmäterapia'],
#     ['CBASP']]},
#   {'buildings': [{'value': '0/JYU/', 'translated': 'Jyväskylän yliopisto'}],
#    'subjects': [['eye diseases'],
#     ['facial expressions'],
#     ['visuality'],
#     ['recognition'],
#     ['facial recognition'],
#     ['age-related eye diseases'],
#     ['bevacizumab'],
#     ['face recognition'],
#     ['EEG'],
#     ['N170']]},
#   {'buildings': [{'value': '0/JYU/', 'translated': 'Jyväskylän yliopisto'}],
#    'subjects': [['MS-tauti'],
#     ['potilaat'],
#     ['kognitio'],
#     ['kognitiiviset prosessit'],
#     ['arviointi'],
#     ['elämänlaatu'],
#     ['heikentyminen'],
#     ['uupumus'],
#     ['neuropsykologia'],
#     ['neurofysiologia'],
#     ['mittaus'],
#     ['EEG'],
#     ['CNV'],
#     ['P3'],
#     ['cognition'],
#     ['fatigue'],
#     ['multiple sclerosis'],
#     ['quality of life']]},
#   {'buildings': [{'value': '0/JYU/', 'translated': 'Jyväskylän yliopisto'},
#     {'value': '1/JYU/100/', 'translated': 'Pääkirjasto'},
#     {'value': '1/JYU/9999/', 'translated': 'Muu'},
#     {'value': '2/JYU/100/2/', 'translated': 'Ei kotilainaan'}],
#    'subjects': [['MS-tauti'],
#     ['potilaat'],
#     ['kognitio'],
#     ['kognitiiviset prosessit'],
#     ['arviointi'],
#     ['elämänlaatu'],
#     ['heikentyminen'],
#     ['uupumus'],
#     ['neuropsykologia'],
#     ['neurofysiologia'],
#     ['mittaus'],
#     ['EEG'],
#     ['multiple sclerosis'],
#     ['fatigue'],
#     ['cognition'],
#     ['CNV'],
#     ['P3'],
#     ['quality of life']]},
#   {'buildings': [{'value': '0/JYU/', 'translated': 'Jyväskylän yliopisto'}],
#    'subjects': [['masennus'], ['ilmeet'], ['EEG']]},
#   {'buildings': [{'value': '0/JYU/', 'translated': 'Jyväskylän yliopisto'}],
#    'subjects': [['masennus'], ['ilmeet'], ['EEG'], ['ikääntyneet']]},
#   {'buildings': [{'value': '0/helka/', 'translated': 'Helka-kirjastot'},
#     {'value': '1/helka/601/', 'translated': 'Viikin kampuskirjasto'},
#     {'value': '2/helka/601/601/', 'translated': 'laina-aika 28 vrk'}],
#    'subjects': [['Electroencephalography.'],
#     ['Magnetoencephalography.'],
#     ['Short-term memory.'],
#     ['EEG'],
#     ['fysiologia ja neurotiede'],
#     ['hermoverkko'],
#     ['MEG'],
#     ['työmuisti']]},
#   {'buildings': [{'value': '0/AALTO/', 'translated': 'Aalto-yliopisto'},
#     {'value': '1/AALTO/ota/', 'translated': 'Oppimiskeskus'},
#     {'value': '2/AALTO/ota/13/', 'translated': 'K-krs, lainattavat, 28 vrk'}],
#    'subjects': [['aivotutkimus'],
#     ['kuvantaminen'],
#     ['magneettitutkimus'],
#     ['EEG'],
#     ['MEG'],
#     ['Magnetoencephalography', 'methods'],
#     ['Electroencephalography', 'methods'],
#     ['Brain', 'physiology'],
#     ['Brain Mapping'],
#     ['Brain Diseases', 'diagnosis']]},
#   {'buildings': [{'value': '0/NLF/', 'translated': 'Kansalliskirjasto'},
#     {'value': '1/NLF/arto/', 'translated': 'Arto'}],
#    'subjects': [['epilepsia'],
#     ['hermoston taudit'],
#     ['diagnostiikka'],
#     ['magneettitutkimus'],
#     ['EEG'],
#     ['oireet']]},
#   {'buildings': [{'value': '0/NLF/', 'translated': 'Kansalliskirjasto'},
#     {'value': '1/NLF/arto/', 'translated': 'Arto'}],
#    'subjects': [['Vilppula, Anitta.'],
#     ['kuvantaminen'],
#     ['röntgentutkimus'],
#     ['magneettitutkimus'],
#     ['ultraäänitutkimus'],
#     ['tietokonetomografia'],
#     ['EEG'],
#     ['diagnostiikka']]},
#   {'buildings': [{'value': '0/NLF/', 'translated': 'Kansalliskirjasto'},
#     {'value': '1/NLF/arto/', 'translated': 'Arto'}],
#    'subjects': [['epilepsia'],
#     ['liitännäistaudit'],
#     ['uni'],
#     ['hengitys'],
#     ['häiriöt'],
#     ['esiintyvyys'],
#     ['tutkimus'],
#     ['EEG'],
#     ['kyselytutkimus'],
#     ['univaje'],
#     ['väsymys'],
#     ['uniapnea-oireyhtymä'],
#     ['unihäiriöt'],
#     ['äkkikuolema'],
#     ['kuolleisuus'],
#     ['hoitomenetelmät'],
#     ['lääkehoito'],
#     ['Suomi'],
#     ['unipolygrafia'],
#     ['obstruktiivinen uniapnea'],
#     ['CPAP'],
#     ['temporaaliepilepsia'],
#     ['otsolohkoepilepsia']]},
#   {'buildings': [{'value': '0/NLF/', 'translated': 'Kansalliskirjasto'},
#     {'value': '1/NLF/arto/', 'translated': 'Arto'}],
#    'subjects': [['robotit'],
#     ['tekoäly'],
#     ['uhkakuvat'],
#     ['autonomiset järjestelmät'],
#     ['keksinnöt'],
#     ['innovaatiot'],
#     ['ihminen-konejärjestelmät'],
#     ['algoritmit'],
#     ['aivotutkimus'],
#     ['robotiikka'],
#     ['hakkerointi'],
#     ['ihminen'],
#     ['sotatekniikka'],
#     ['manipulaatio'],
#     ['telepatia'],
#     ['magneettitutkimus'],
#     ['kauko-ohjaus'],
#     ['koneet'],
#     ['muisti'],
#     ['EEG'],
#     ['tietoturva'],
#     ['teknologia'],
#     ['ajatukset']]}],
#  'status': 'OK'}

# %%
def get_and_beautify_data_from_api(lookfor = "EEG", year = "2017") : 
    result = fc().search(lookfor=lookfor,
                           search_type=fst.Subject,
                           fields=["buildings", "subjects"],
                           filters=["main_date_str:{year}".format(year = year)],
                           page=1,
                           limit=100)
    b_result = {}
    b_result['resultCount'] = result['resultCount']
    tmp_records = []
    for record in result['records']:
        tmp_record = {}
        tmp_record['building'] = record['buildings'][0]['translated']
        tmp_record['subjects'] = [subject[0] for subject in record['subjects']]
        tmp_records.append(tmp_record)
    b_result['records'] = tmp_records
    return b_result

result = get_and_beautify_data_from_api()

# %%
def count_orgs(records):
    orgs_count = {} 
    for record in records:
        try : 
            orgs_count[record['building']] += 1 
        except KeyError:
            orgs_count[record['building']]  = 1
    return orgs_count

orgs_count = count_orgs(result['records'])

# %%
def count_subjects(records):
    subject_count = {} 
    for record in records: 
        for subject in record['subjects']:
            subject = subject.lower() 
            try: 
                subject_count [subject] += 1 
            except KeyError: 
                subject_count [subject] = 1
    return subject_count
            
subjects_count = count_subjects(result['records'])

# %%
subjects_count.keys()
# Out:
# dict_keys(['mietiskely', 'tietoinen läsnäolo', 'eeg', 'sanat', 'prosessointi', 'merkitys', 'organisaatiot', 'herätevaste', 'elektromyografia', 'korrelaatio', 'silmänliikkeet', 'neuroverkot', 'emd', 'huippukorrelaatioanalyysi', 'responses', 'emotions', 'neurons', 'spectral linear discriminant analysis', 'brain', 'syke', 'heart rate variability', 'hrv', 'cardiac cycle', 'learning', 'trace conditioning', 'electroencephalography.', 'magnetoencephalography.', 'short-term memory.', 'fysiologia ja neurotiede', 'hermoverkko', 'meg', 'työmuisti', 'masennus', 'kasvontunnistus', 'ilmeet', 'tunteet', 'tulkinta', 'aivotutkimus', 'neuropsykologia', 'psykoterapia', 'kognitiivinen terapia', 'käyttäytymisterapia', 'ryhmäterapia', 'cbasp', 'eye diseases', 'facial expressions', 'visuality', 'recognition', 'facial recognition', 'age-related eye diseases', 'bevacizumab', 'face recognition', 'n170', 'ms-tauti', 'potilaat', 'kognitio', 'kognitiiviset prosessit', 'arviointi', 'elämänlaatu', 'heikentyminen', 'uupumus', 'neurofysiologia', 'mittaus', 'cnv', 'p3', 'cognition', 'fatigue', 'multiple sclerosis', 'quality of life', 'ikääntyneet', 'kuvantaminen', 'magneettitutkimus', 'magnetoencephalography', 'electroencephalography', 'brain mapping', 'brain diseases', 'epilepsia', 'hermoston taudit', 'diagnostiikka', 'oireet', 'vilppula, anitta.', 'röntgentutkimus', 'ultraäänitutkimus', 'tietokonetomografia', 'liitännäistaudit', 'uni', 'hengitys', 'häiriöt', 'esiintyvyys', 'tutkimus', 'kyselytutkimus', 'univaje', 'väsymys', 'uniapnea-oireyhtymä', 'unihäiriöt', 'äkkikuolema', 'kuolleisuus', 'hoitomenetelmät', 'lääkehoito', 'suomi', 'unipolygrafia', 'obstruktiivinen uniapnea', 'cpap', 'temporaaliepilepsia', 'otsolohkoepilepsia', 'robotit', 'tekoäly', 'uhkakuvat', 'autonomiset järjestelmät', 'keksinnöt', 'innovaatiot', 'ihminen-konejärjestelmät', 'algoritmit', 'robotiikka', 'hakkerointi', 'ihminen', 'sotatekniikka', 'manipulaatio', 'telepatia', 'kauko-ohjaus', 'koneet', 'muisti', 'tietoturva', 'teknologia', 'ajatukset'])

# %%
len(subjects_count)
# Out:
# 125

# %%
{}.fromkeys(subjects_count.keys())
# Out:
# {'mietiskely': None,
#  'tietoinen läsnäolo': None,
#  'eeg': None,
#  'sanat': None,
#  'prosessointi': None,
#  'merkitys': None,
#  'organisaatiot': None,
#  'herätevaste': None,
#  'elektromyografia': None,
#  'korrelaatio': None,
#  'silmänliikkeet': None,
#  'neuroverkot': None,
#  'emd': None,
#  'huippukorrelaatioanalyysi': None,
#  'responses': None,
#  'emotions': None,
#  'neurons': None,
#  'spectral linear discriminant analysis': None,
#  'brain': None,
#  'syke': None,
#  'heart rate variability': None,
#  'hrv': None,
#  'cardiac cycle': None,
#  'learning': None,
#  'trace conditioning': None,
#  'electroencephalography.': None,
#  'magnetoencephalography.': None,
#  'short-term memory.': None,
#  'fysiologia ja neurotiede': None,
#  'hermoverkko': None,
#  'meg': None,
#  'työmuisti': None,
#  'masennus': None,
#  'kasvontunnistus': None,
#  'ilmeet': None,
#  'tunteet': None,
#  'tulkinta': None,
#  'aivotutkimus': None,
#  'neuropsykologia': None,
#  'psykoterapia': None,
#  'kognitiivinen terapia': None,
#  'käyttäytymisterapia': None,
#  'ryhmäterapia': None,
#  'cbasp': None,
#  'eye diseases': None,
#  'facial expressions': None,
#  'visuality': None,
#  'recognition': None,
#  'facial recognition': None,
#  'age-related eye diseases': None,
#  'bevacizumab': None,
#  'face recognition': None,
#  'n170': None,
#  'ms-tauti': None,
#  'potilaat': None,
#  'kognitio': None,
#  'kognitiiviset prosessit': None,
#  'arviointi': None,
#  'elämänlaatu': None,
#  'heikentyminen': None,
#  'uupumus': None,
#  'neurofysiologia': None,
#  'mittaus': None,
#  'cnv': None,
#  'p3': None,
#  'cognition': None,
#  'fatigue': None,
#  'multiple sclerosis': None,
#  'quality of life': None,
#  'ikääntyneet': None,
#  'kuvantaminen': None,
#  'magneettitutkimus': None,
#  'magnetoencephalography': None,
#  'electroencephalography': None,
#  'brain mapping': None,
#  'brain diseases': None,
#  'epilepsia': None,
#  'hermoston taudit': None,
#  'diagnostiikka': None,
#  'oireet': None,
#  'vilppula, anitta.': None,
#  'röntgentutkimus': None,
#  'ultraäänitutkimus': None,
#  'tietokonetomografia': None,
#  'liitännäistaudit': None,
#  'uni': None,
#  'hengitys': None,
#  'häiriöt': None,
#  'esiintyvyys': None,
#  'tutkimus': None,
#  'kyselytutkimus': None,
#  'univaje': None,
#  'väsymys': None,
#  'uniapnea-oireyhtymä': None,
#  'unihäiriöt': None,
#  'äkkikuolema': None,
#  'kuolleisuus': None,
#  'hoitomenetelmät': None,
#  'lääkehoito': None,
#  'suomi': None,
#  'unipolygrafia': None,
#  'obstruktiivinen uniapnea': None,
#  'cpap': None,
#  'temporaaliepilepsia': None,
#  'otsolohkoepilepsia': None,
#  'robotit': None,
#  'tekoäly': None,
#  'uhkakuvat': None,
#  'autonomiset järjestelmät': None,
#  'keksinnöt': None,
#  'innovaatiot': None,
#  'ihminen-konejärjestelmät': None,
#  'algoritmit': None,
#  'robotiikka': None,
#  'hakkerointi': None,
#  'ihminen': None,
#  'sotatekniikka': None,
#  'manipulaatio': None,
#  'telepatia': None,
#  'kauko-ohjaus': None,
#  'koneet': None,
#  'muisti': None,
#  'tietoturva': None,
#  'teknologia': None,
#  'ajatukset': None}

# %%
{key: {key:0 for key in subjects_count.keys()} for key in subjects_count.keys() }
# Out:
# {'mietiskely': {'mietiskely': 0,
#   'tietoinen läsnäolo': 0,
#   'eeg': 0,
#   'sanat': 0,
#   'prosessointi': 0,
#   'merkitys': 0,
#   'organisaatiot': 0,
#   'herätevaste': 0,
#   'elektromyografia': 0,
#   'korrelaatio': 0,
#   'silmänliikkeet': 0,
#   'neuroverkot': 0,
#   'emd': 0,
#   'huippukorrelaatioanalyysi': 0,
#   'responses': 0,
#   'emotions': 0,
#   'neurons': 0,
#   'spectral linear discriminant analysis': 0,
#   'brain': 0,
#   'syke': 0,
#   'heart rate variability': 0,
#   'hrv': 0,
#   'cardiac cycle': 0,
#   'learning': 0,
#   'trace conditioning': 0,
#   'electroencephalography.': 0,
#   'magnetoencephalography.': 0,
#   'short-term memory.': 0,
#   'fysiologia ja neurotiede': 0,
#   'hermoverkko': 0,
#   'meg': 0,
#   'työmuisti': 0,
#   'masennus': 0,
#   'kasvontunnistus': 0,
#   'ilmeet': 0,
#   'tunteet': 0,
#   'tulkinta': 0,
#   'aivotutkimus': 0,
#   'neuropsykologia': 0,
#   'psykoterapia': 0,
#   'kognitiivinen terapia': 0,
#   'käyttäytymisterapia': 0,
#   'ryhmäterapia': 0,
#   'cbasp': 0,
#   'eye diseases': 0,
#   'facial expressions': 0,
#   'visuality': 0,
#   'recognition': 0,
#   'facial recognition': 0,
#   'age-related eye diseases': 0,
#   'bevacizumab': 0,
#   'face recognition': 0,
#   'n170': 0,
#   'ms-tauti': 0,
#   'potilaat': 0,
#   'kognitio': 0,
#   'kognitiiviset prosessit': 0,
#   'arviointi': 0,
#   'elämänlaatu': 0,
#   'heikentyminen': 0,
#   'uupumus': 0,
#   'neurofysiologia': 0,
#   'mittaus': 0,
#   'cnv': 0,
#   'p3': 0,
#   'cognition': 0,
#   'fatigue': 0,
#   'multiple sclerosis': 0,
#   'quality of life': 0,
#   'ikääntyneet': 0,
#   'kuvantaminen': 0,
#   'magneettitutkimus': 0,
#   'magnetoencephalography': 0,
#   'electroencephalography': 0,
#   'brain mapping': 0,
#   'brain diseases': 0,
#   'epilepsia': 0,
#   'hermoston taudit': 0,
#   'diagnostiikka': 0,
#   'oireet': 0,
#   'vilppula, anitta.': 0,
#   'röntgentutkimus': 0,
#   'ultraäänitutkimus': 0,
#   'tietokonetomografia': 0,
#   'liitännäistaudit': 0,
#   'uni': 0,
#   'hengitys': 0,
#   'häiriöt': 0,
#   'esiintyvyys': 0,
#   'tutkimus': 0,
#   'kyselytutkimus': 0,
#   'univaje': 0,
#   'väsymys': 0,
#   'uniapnea-oireyhtymä': 0,
#   'unihäiriöt': 0,
#   'äkkikuolema': 0,
#   'kuolleisuus': 0,
#   'hoitomenetelmät': 0,
#   'lääkehoito': 0,
#   'suomi': 0,
#   'unipolygrafia': 0,
#   'obstruktiivinen uniapnea': 0,
#   'cpap': 0,
#   'temporaaliepilepsia': 0,
#   'otsolohkoepilepsia': 0,
#   'robotit': 0,
#   'tekoäly': 0,
#   'uhkakuvat': 0,
#   'autonomiset järjestelmät': 0,
#   'keksinnöt': 0,
#   'innovaatiot': 0,
#   'ihminen-konejärjestelmät': 0,
#   'algoritmit': 0,
#   'robotiikka': 0,
#   'hakkerointi': 0,
#   'ihminen': 0,
#   'sotatekniikka': 0,
#   'manipulaatio': 0,
#   'telepatia': 0,
#   'kauko-ohjaus': 0,
#   'koneet': 0,
#   'muisti': 0,
#   'tietoturva': 0,
#   'teknologia': 0,
#   'ajatukset': 0},
#  'tietoinen läsnäolo': {'mietiskely': 0,
#   'tietoinen läsnäolo': 0,
#   'eeg': 0,
#   'sanat': 0,
#   'prosessointi': 0,
#   'merkitys': 0,
#   'organisaatiot': 0,
#   'herätevaste': 0,
#   'elektromyografia': 0,
#   'korrelaatio': 0,
#   'silmänliikkeet': 0,
#   'neuroverkot': 0,
#   'emd': 0,
#   'huippukorrelaatioanalyysi': 0,
#   'responses': 0,
#   'emotions': 0,
#   'neurons': 0,
#   'spectral linear discriminant analysis': 0,
#   'brain': 0,
#   'syke': 0,
#   'heart rate variability': 0,
#   'hrv': 0,
#   'cardiac cycle': 0,
#   'learning': 0,
#   'trace conditioning': 0,
#   'electroencephalography.': 0,
#   'magnetoencephalography.': 0,
#   'short-term memory.': 0,
#   'fysiologia ja neurotiede': 0,
#   'hermoverkko': 0,
#   'meg': 0,
#   'työmuisti': 0,
#   'masennus': 0,
#   'kasvontunnistus': 0,
#   'ilmeet': 0,
#   'tunteet': 0,
#   'tulkinta': 0,
#   'aivotutkimus': 0,
#   'neuropsykologia': 0,
#   'psykoterapia': 0,
#   'kognitiivinen terapia': 0,
#   'käyttäytymisterapia': 0,
#   'ryhmäterapia': 0,
#   'cbasp': 0,
#   'eye diseases': 0,
#   'facial expressions': 0,
#   'visuality': 0,
#   'recognition': 0,
#   'facial recognition': 0,
#   'age-related eye diseases': 0,
#   'bevacizumab': 0,
#   'face recognition': 0,
#   'n170': 0,
#   'ms-tauti': 0,
#   'potilaat': 0,
#   'kognitio': 0,
#   'kognitiiviset prosessit': 0,
#   'arviointi': 0,
#   'elämänlaatu': 0,
#   'heikentyminen': 0,
#   'uupumus': 0,
#   'neurofysiologia': 0,
#   'mittaus': 0,
#   'cnv': 0,
#   'p3': 0,
#   'cognition': 0,
#   'fatigue': 0,
#   'multiple sclerosis': 0,
#   'quality of life': 0,
#   'ikääntyneet': 0,
#   'kuvantaminen': 0,
#   'magneettitutkimus': 0,
#   'magnetoencephalography': 0,
#   'electroencephalography': 0,
#   'brain mapping': 0,
#   'brain diseases': 0,
#   'epilepsia': 0,
#   'hermoston taudit': 0,
#   'diagnostiikka': 0,
#   'oireet': 0,
#   'vilppula, anitta.': 0,
#   'röntgentutkimus': 0,
#   'ultraäänitutkimus': 0,
#   'tietokonetomografia': 0,
#   'liitännäistaudit': 0,
#   'uni': 0,
#   'hengitys': 0,
#   'häiriöt': 0,
#   'esiintyvyys': 0,
#   'tutkimus': 0,
#   'kyselytutkimus': 0,
#   'univaje': 0,
#   'väsymys': 0,
#   'uniapnea-oireyhtymä': 0,
#   'unihäiriöt': 0,
#   'äkkikuolema': 0,
#   'kuolleisuus': 0,
#   'hoitomenetelmät': 0,
#   'lääkehoito': 0,
#   'suomi': 0,
#   'unipolygrafia': 0,
#   'obstruktiivinen uniapnea': 0,
#   'cpap': 0,
#   'temporaaliepilepsia': 0,
#   'otsolohkoepilepsia': 0,
#   'robotit': 0,
#   'tekoäly': 0,
#   'uhkakuvat': 0,
#   'autonomiset järjestelmät': 0,
#   'keksinnöt': 0,
#   'innovaatiot': 0,
#   'ihminen-konejärjestelmät': 0,
#   'algoritmit': 0,
#   'robotiikka': 0,
#   'hakkerointi': 0,
#   'ihminen': 0,
#   'sotatekniikka': 0,
#   'manipulaatio': 0,
#   'telepatia': 0,
#   'kauko-ohjaus': 0,
#   'koneet': 0,
#   'muisti': 0,
#   'tietoturva': 0,
#   'teknologia': 0,
#   'ajatukset': 0},
#  'eeg': {'mietiskely': 0,
#   'tietoinen läsnäolo': 0,
#   'eeg': 0,
#   'sanat': 0,
#   'prosessointi': 0,
#   'merkitys': 0,
#   'organisaatiot': 0,
#   'herätevaste': 0,
#   'elektromyografia': 0,
#   'korrelaatio': 0,
#   'silmänliikkeet': 0,
#   'neuroverkot': 0,
#   'emd': 0,
#   'huippukorrelaatioanalyysi': 0,
#   'responses': 0,
#   'emotions': 0,
#   'neurons': 0,
#   'spectral linear discriminant analysis': 0,
#   'brain': 0,
#   'syke': 0,
#   'heart rate variability': 0,
#   'hrv': 0,
#   'cardiac cycle': 0,
#   'learning': 0,
#   'trace conditioning': 0,
#   'electroencephalography.': 0,
#   'magnetoencephalography.': 0,
#   'short-term memory.': 0,
#   'fysiologia ja neurotiede': 0,
#   'hermoverkko': 0,
#   'meg': 0,
#   'työmuisti': 0,
#   'masennus': 0,
#   'kasvontunnistus': 0,
#   'ilmeet': 0,
#   'tunteet': 0,
#   'tulkinta': 0,
#   'aivotutkimus': 0,
#   'neuropsykologia': 0,
#   'psykoterapia': 0,
#   'kognitiivinen terapia': 0,
#   'käyttäytymisterapia': 0,
#   'ryhmäterapia': 0,
#   'cbasp': 0,
#   'eye diseases': 0,
#   'facial expressions': 0,
#   'visuality': 0,
#   'recognition': 0,
#   'facial recognition': 0,
#   'age-related eye diseases': 0,
#   'bevacizumab': 0,
#   'face recognition': 0,
#   'n170': 0,
#   'ms-tauti': 0,
#   'potilaat': 0,
#   'kognitio': 0,
#   'kognitiiviset prosessit': 0,
#   'arviointi': 0,
#   'elämänlaatu': 0,
#   'heikentyminen': 0,
#   'uupumus': 0,
#   'neurofysiologia': 0,
#   'mittaus': 0,
#   'cnv': 0,
#   'p3': 0,
#   'cognition': 0,
#   'fatigue': 0,
#   'multiple sclerosis': 0,
#   'quality of life': 0,
#   'ikääntyneet': 0,
#   'kuvantaminen': 0,
#   'magneettitutkimus': 0,
#   'magnetoencephalography': 0,
#   'electroencephalography': 0,
#   'brain mapping': 0,
#   'brain diseases': 0,
#   'epilepsia': 0,
#   'hermoston taudit': 0,
#   'diagnostiikka': 0,
#   'oireet': 0,
#   'vilppula, anitta.': 0,
#   'röntgentutkimus': 0,
#   'ultraäänitutkimus': 0,
#   'tietokonetomografia': 0,
#   'liitännäistaudit': 0,
#   'uni': 0,
#   'hengitys': 0,
#   'häiriöt': 0,
#   'esiintyvyys': 0,
#   'tutkimus': 0,
#   'kyselytutkimus': 0,
#   'univaje': 0,
#   'väsymys': 0,
#   'uniapnea-oireyhtymä': 0,
#   'unihäiriöt': 0,
#   'äkkikuolema': 0,
#   'kuolleisuus': 0,
#   'hoitomenetelmät': 0,
#   'lääkehoito': 0,
#   'suomi': 0,
#   'unipolygrafia': 0,
#   'obstruktiivinen uniapnea': 0,
#   'cpap': 0,
#   'temporaaliepilepsia': 0,
#   'otsolohkoepilepsia': 0,
#   'robotit': 0,
#   'tekoäly': 0,
#   'uhkakuvat': 0,
#   'autonomiset järjestelmät': 0,
#   'keksinnöt': 0,
#   'innovaatiot': 0,
#   'ihminen-konejärjestelmät': 0,
#   'algoritmit': 0,
#   'robotiikka': 0,
#   'hakkerointi': 0,
#   'ihminen': 0,
#   'sotatekniikka': 0,
#   'manipulaatio': 0,
#   'telepatia': 0,
#   'kauko-ohjaus': 0,
#   'koneet': 0,
#   'muisti': 0,
#   'tietoturva': 0,
#   'teknologia': 0,
#   'ajatukset': 0},
#  'sanat': {'mietiskely': 0,
#   'tietoinen läsnäolo': 0,
#   'eeg': 0,
#   'sanat': 0,
#   'prosessointi': 0,
#   'merkitys': 0,
#   'organisaatiot': 0,
#   'herätevaste': 0,
#   'elektromyografia': 0,
#   'korrelaatio': 0,
#   'silmänliikkeet': 0,
#   'neuroverkot': 0,
#   'emd': 0,
#   'huippukorrelaatioanalyysi': 0,
#   'responses': 0,
#   'emotions': 0,
#   'neurons': 0,
#   'spectral linear discriminant analysis': 0,
#   'brain': 0,
#   'syke': 0,
#   'heart rate variability': 0,
#   'hrv': 0,
#   'cardiac cycle': 0,
#   'learning': 0,
#   'trace conditioning': 0,
#   'electroencephalography.': 0,
#   'magnetoencephalography.': 0,
#   'short-term memory.': 0,
#   'fysiologia ja neurotiede': 0,
#   'hermoverkko': 0,
#   'meg': 0,
#   'työmuisti': 0,
#   'masennus': 0,
#   'kasvontunnistus': 0,
#   'ilmeet': 0,
#   'tunteet': 0,
#   'tulkinta': 0,
#   'aivotutkimus': 0,
#   'neuropsykologia': 0,
#   'psykoterapia': 0,
#   'kognitiivinen terapia': 0,
#   'käyttäytymisterapia': 0,
#   'ryhmäterapia': 0,
#   'cbasp': 0,
#   'eye diseases': 0,
#   'facial expressions': 0,
#   'visuality': 0,
#   'recognition': 0,
#   'facial recognition': 0,
#   'age-related eye diseases': 0,
#   'bevacizumab': 0,
#   'face recognition': 0,
#   'n170': 0,
#   'ms-tauti': 0,
#   'potilaat': 0,
#   'kognitio': 0,
#   'kognitiiviset prosessit': 0,
#   'arviointi': 0,
#   'elämänlaatu': 0,
#   'heikentyminen': 0,
#   'uupumus': 0,
#   'neurofysiologia': 0,
#   'mittaus': 0,
#   'cnv': 0,
#   'p3': 0,
#   'cognition': 0,
#   'fatigue': 0,
#   'multiple sclerosis': 0,
#   'quality of life': 0,
#   'ikääntyneet': 0,
#   'kuvantaminen': 0,
#   'magneettitutkimus': 0,
#   'magnetoencephalography': 0,
#   'electroencephalography': 0,
#   'brain mapping': 0,
#   'brain diseases': 0,
#   'epilepsia': 0,
#   'hermoston taudit': 0,
#   'diagnostiikka': 0,
#   'oireet': 0,
#   'vilppula, anitta.': 0,
#   'röntgentutkimus': 0,
#   'ultraäänitutkimus': 0,
#   'tietokonetomografia': 0,
#   'liitännäistaudit': 0,
#   'uni': 0,
#   'hengitys': 0,
#   'häiriöt': 0,
#   'esiintyvyys': 0,
#   'tutkimus': 0,
#   'kyselytutkimus': 0,
#   'univaje': 0,
#   'väsymys': 0,
#   'uniapnea-oireyhtymä': 0,
#   'unihäiriöt': 0,
#   'äkkikuolema': 0,
#   'kuolleisuus': 0,
#   'hoitomenetelmät': 0,
#   'lääkehoito': 0,
#   'suomi': 0,
#   'unipolygrafia': 0,
#   'obstruktiivinen uniapnea': 0,
#   'cpap': 0,
#   'temporaaliepilepsia': 0,
#   'otsolohkoepilepsia': 0,
#   'robotit': 0,
#   'tekoäly': 0,
#   'uhkakuvat': 0,
#   'autonomiset järjestelmät': 0,
#   'keksinnöt': 0,
#   'innovaatiot': 0,
#   'ihminen-konejärjestelmät': 0,
#   'algoritmit': 0,
#   'robotiikka': 0,
#   'hakkerointi': 0,
#   'ihminen': 0,
#   'sotatekniikka': 0,
#   'manipulaatio': 0,
#   'telepatia': 0,
#   'kauko-ohjaus': 0,
#   'koneet': 0,
#   'muisti': 0,
#   'tietoturva': 0,
#   'teknologia': 0,
#   'ajatukset': 0},
#  'prosessointi': {'mietiskely': 0,
#   'tietoinen läsnäolo': 0,
#   'eeg': 0,
#   'sanat': 0,
#   'prosessointi': 0,
#   'merkitys': 0,
#   'organisaatiot': 0,
#   'herätevaste': 0,
#   'elektromyografia': 0,
#   'korrelaatio': 0,
#   'silmänliikkeet': 0,
#   'neuroverkot': 0,
#   'emd': 0,
#   'huippukorrelaatioanalyysi': 0,
#   'responses': 0,
#   'emotions': 0,
#   'neurons': 0,
#   'spectral linear discriminant analysis': 0,
#   'brain': 0,
#   'syke': 0,
#   'heart rate variability': 0,
#   'hrv': 0,
#   'cardiac cycle': 0,
#   'learning': 0,
#   'trace conditioning': 0,
#   'electroencephalography.': 0,
#   'magnetoencephalography.': 0,
#   'short-term memory.': 0,
#   'fysiologia ja neurotiede': 0,
#   'hermoverkko': 0,
#   'meg': 0,
#   'työmuisti': 0,
#   'masennus': 0,
#   'kasvontunnistus': 0,
#   'ilmeet': 0,
#   'tunteet': 0,
#   'tulkinta': 0,
#   'aivotutkimus': 0,
#   'neuropsykologia': 0,
#   'psykoterapia': 0,
#   'kognitiivinen terapia': 0,
#   'käyttäytymisterapia': 0,
#   'ryhmäterapia': 0,
#   'cbasp': 0,
#   'eye diseases': 0,
#   'facial expressions': 0,
#   'visuality': 0,
#   'recognition': 0,
#   'facial recognition': 0,
#   'age-related eye diseases': 0,
#   'bevacizumab': 0,
#   'face recognition': 0,
#   'n170': 0,
#   'ms-tauti': 0,
#   'potilaat': 0,
#   'kognitio': 0,
#   'kognitiiviset prosessit': 0,
#   'arviointi': 0,
#   'elämänlaatu': 0,
#   'heikentyminen': 0,
#   'uupumus': 0,
#   'neurofysiologia': 0,
#   'mittaus': 0,
#   'cnv': 0,
#   'p3': 0,
#   'cognition': 0,
#   'fatigue': 0,
#   'multiple sclerosis': 0,
#   'quality of life': 0,
#   'ikääntyneet': 0,
#   'kuvantaminen': 0,
#   'magneettitutkimus': 0,
#   'magnetoencephalography': 0,
#   'electroencephalography': 0,
#   'brain mapping': 0,
#   'brain diseases': 0,
#   'epilepsia': 0,
#   'hermoston taudit': 0,
#   'diagnostiikka': 0,
#   'oireet': 0,
#   'vilppula, anitta.': 0,
#   'röntgentutkimus': 0,
#   'ultraäänitutkimus': 0,
#   'tietokonetomografia': 0,
#   'liitännäistaudit': 0,
#   'uni': 0,
#   'hengitys': 0,
#   'häiriöt': 0,
#   'esiintyvyys': 0,
#   'tutkimus': 0,
#   'kyselytutkimus': 0,
#   'univaje': 0,
#   'väsymys': 0,
#   'uniapnea-oireyhtymä': 0,
#   'unihäiriöt': 0,
#   'äkkikuolema': 0,
#   'kuolleisuus': 0,
#   'hoitomenetelmät': 0,
#   'lääkehoito': 0,
#   'suomi': 0,
#   'unipolygrafia': 0,
#   'obstruktiivinen uniapnea': 0,
#   'cpap': 0,
#   'temporaaliepilepsia': 0,
#   'otsolohkoepilepsia': 0,
#   'robotit': 0,
#   'tekoäly': 0,
#   'uhkakuvat': 0,
#   'autonomiset järjestelmät': 0,
#   'keksinnöt': 0,
#   'innovaatiot': 0,
#   'ihminen-konejärjestelmät': 0,
#   'algoritmit': 0,
#   'robotiikka': 0,
#   'hakkerointi': 0,
#   'ihminen': 0,
#   'sotatekniikka': 0,
#   'manipulaatio': 0,
#   'telepatia': 0,
#   'kauko-ohjaus': 0,
#   'koneet': 0,
#   'muisti': 0,
#   'tietoturva': 0,
#   'teknologia': 0,
#   'ajatukset': 0},
#  'merkitys': {'mietiskely': 0,
#   'tietoinen läsnäolo': 0,
#   'eeg': 0,
#   'sanat': 0,
#   'prosessointi': 0,
#   'merkitys': 0,
#   'organisaatiot': 0,
#   'herätevaste': 0,
#   'elektromyografia': 0,
#   'korrelaatio': 0,
#   'silmänliikkeet': 0,
#   'neuroverkot': 0,
#   'emd': 0,
#   'huippukorrelaatioanalyysi': 0,
#   'responses': 0,
#   'emotions': 0,
#   'neurons': 0,
#   'spectral linear discriminant analysis': 0,
#   'brain': 0,
#   'syke': 0,
#   'heart rate variability': 0,
#   'hrv': 0,
#   'cardiac cycle': 0,
#   'learning': 0,
#   'trace conditioning': 0,
#   'electroencephalography.': 0,
#   'magnetoencephalography.': 0,
#   'short-term memory.': 0,
#   'fysiologia ja neurotiede': 0,
#   'hermoverkko': 0,
#   'meg': 0,
#   'työmuisti': 0,
#   'masennus': 0,
#   'kasvontunnistus': 0,
#   'ilmeet': 0,
#   'tunteet': 0,
#   'tulkinta': 0,
#   'aivotutkimus': 0,
#   'neuropsykologia': 0,
#   'psykoterapia': 0,
#   'kognitiivinen terapia': 0,
#   'käyttäytymisterapia': 0,
#   'ryhmäterapia': 0,
#   'cbasp': 0,
#   'eye diseases': 0,
#   'facial expressions': 0,
#   'visuality': 0,
#   'recognition': 0,
#   'facial recognition': 0,
#   'age-related eye diseases': 0,
#   'bevacizumab': 0,
#   'face recognition': 0,
#   'n170': 0,
#   'ms-tauti': 0,
#   'potilaat': 0,
#   'kognitio': 0,
#   'kognitiiviset prosessit': 0,
#   'arviointi': 0,
#   'elämänlaatu': 0,
#   'heikentyminen': 0,
#   'uupumus': 0,
#   'neurofysiologia': 0,
#   'mittaus': 0,
#   'cnv': 0,
#   'p3': 0,
#   'cognition': 0,
#   'fatigue': 0,
#   'multiple sclerosis': 0,
#   'quality of life': 0,
#   'ikääntyneet': 0,
#   'kuvantaminen': 0,
#   'magneettitutkimus': 0,
#   'magnetoencephalography': 0,
#   'electroencephalography': 0,
#   'brain mapping': 0,
#   'brain diseases': 0,
#   'epilepsia': 0,
#   'hermoston taudit': 0,
#   'diagnostiikka': 0,
#   'oireet': 0,
#   'vilppula, anitta.': 0,
#   'röntgentutkimus': 0,
#   'ultraäänitutkimus': 0,
#   'tietokonetomografia': 0,
#   'liitännäistaudit': 0,
#   'uni': 0,
#   'hengitys': 0,
#   'häiriöt': 0,
#   'esiintyvyys': 0,
#   'tutkimus': 0,
#   'kyselytutkimus': 0,
#   'univaje': 0,
#   'väsymys': 0,
#   'uniapnea-oireyhtymä': 0,
#   'unihäiriöt': 0,
#   'äkkikuolema': 0,
#   'kuolleisuus': 0,
#   'hoitomenetelmät': 0,
#   'lääkehoito': 0,
#   'suomi': 0,
#   'unipolygrafia': 0,
#   'obstruktiivinen uniapnea': 0,
#   'cpap': 0,
#   'temporaaliepilepsia': 0,
#   'otsolohkoepilepsia': 0,
#   'robotit': 0,
#   'tekoäly': 0,
#   'uhkakuvat': 0,
#   'autonomiset järjestelmät': 0,
#   'keksinnöt': 0,
#   'innovaatiot': 0,
#   'ihminen-konejärjestelmät': 0,
#   'algoritmit': 0,
#   'robotiikka': 0,
#   'hakkerointi': 0,
#   'ihminen': 0,
#   'sotatekniikka': 0,
#   'manipulaatio': 0,
#   'telepatia': 0,
#   'kauko-ohjaus': 0,
#   'koneet': 0,
#   'muisti': 0,
#   'tietoturva': 0,
#   'teknologia': 0,
#   'ajatukset': 0},
#  'organisaatiot': {'mietiskely': 0,
#   'tietoinen läsnäolo': 0,
#   'eeg': 0,
#   'sanat': 0,
#   'prosessointi': 0,
#   'merkitys': 0,
#   'organisaatiot': 0,
#   'herätevaste': 0,
#   'elektromyografia': 0,
#   'korrelaatio': 0,
#   'silmänliikkeet': 0,
#   'neuroverkot': 0,
#   'emd': 0,
#   'huippukorrelaatioanalyysi': 0,
#   'responses': 0,
#   'emotions': 0,
#   'neurons': 0,
#   'spectral linear discriminant analysis': 0,
#   'brain': 0,
#   'syke': 0,
#   'heart rate variability': 0,
#   'hrv': 0,
#   'cardiac cycle': 0,
#   'learning': 0,
#   'trace conditioning': 0,
#   'electroencephalography.': 0,
#   'magnetoencephalography.': 0,
#   'short-term memory.': 0,
#   'fysiologia ja neurotiede': 0,
#   'hermoverkko': 0,
#   'meg': 0,
#   'työmuisti': 0,
#   'masennus': 0,
#   'kasvontunnistus': 0,
#   'ilmeet': 0,
#   'tunteet': 0,
#   'tulkinta': 0,
#   'aivotutkimus': 0,
#   'neuropsykologia': 0,
#   'psykoterapia': 0,
#   'kognitiivinen terapia': 0,
#   'käyttäytymisterapia': 0,
#   'ryhmäterapia': 0,
#   'cbasp': 0,
#   'eye diseases': 0,
#   'facial expressions': 0,
#   'visuality': 0,
#   'recognition': 0,
#   'facial recognition': 0,
#   'age-related eye diseases': 0,
#   'bevacizumab': 0,
#   'face recognition': 0,
#   'n170': 0,
#   'ms-tauti': 0,
#   'potilaat': 0,
#   'kognitio': 0,
#   'kognitiiviset prosessit': 0,
#   'arviointi': 0,
#   'elämänlaatu': 0,
#   'heikentyminen': 0,
#   'uupumus': 0,
#   'neurofysiologia': 0,
#   'mittaus': 0,
#   'cnv': 0,
#   'p3': 0,
#   'cognition': 0,
#   'fatigue': 0,
#   'multiple sclerosis': 0,
#   'quality of life': 0,
#   'ikääntyneet': 0,
#   'kuvantaminen': 0,
#   'magneettitutkimus': 0,
#   'magnetoencephalography': 0,
#   'electroencephalography': 0,
#   'brain mapping': 0,
#   'brain diseases': 0,
#   'epilepsia': 0,
#   'hermoston taudit': 0,
#   'diagnostiikka': 0,
#   'oireet': 0,
#   'vilppula, anitta.': 0,
#   'röntgentutkimus': 0,
#   'ultraäänitutkimus': 0,
#   'tietokonetomografia': 0,
#   'liitännäistaudit': 0,
#   'uni': 0,
#   'hengitys': 0,
#   'häiriöt': 0,
#   'esiintyvyys': 0,
#   'tutkimus': 0,
#   'kyselytutkimus': 0,
#   'univaje': 0,
#   'väsymys': 0,
#   'uniapnea-oireyhtymä': 0,
#   'unihäiriöt': 0,
#   'äkkikuolema': 0,
#   'kuolleisuus': 0,
#   'hoitomenetelmät': 0,
#   'lääkehoito': 0,
#   'suomi': 0,
#   'unipolygrafia': 0,
#   'obstruktiivinen uniapnea': 0,
#   'cpap': 0,
#   'temporaaliepilepsia': 0,
#   'otsolohkoepilepsia': 0,
#   'robotit': 0,
#   'tekoäly': 0,
#   'uhkakuvat': 0,
#   'autonomiset järjestelmät': 0,
#   'keksinnöt': 0,
#   'innovaatiot': 0,
#   'ihminen-konejärjestelmät': 0,
#   'algoritmit': 0,
#   'robotiikka': 0,
#   'hakkerointi': 0,
#   'ihminen': 0,
#   'sotatekniikka': 0,
#   'manipulaatio': 0,
#   'telepatia': 0,
#   'kauko-ohjaus': 0,
#   'koneet': 0,
#   'muisti': 0,
#   'tietoturva': 0,
#   'teknologia': 0,
#   'ajatukset': 0},
#  'herätevaste': {'mietiskely': 0,
#   'tietoinen läsnäolo': 0,
#   'eeg': 0,
#   'sanat': 0,
#   'prosessointi': 0,
#   'merkitys': 0,
#   'organisaatiot': 0,
#   'herätevaste': 0,
#   'elektromyografia': 0,
#   'korrelaatio': 0,
#   'silmänliikkeet': 0,
#   'neuroverkot': 0,
#   'emd': 0,
#   'huippukorrelaatioanalyysi': 0,
#   'responses': 0,
#   'emotions': 0,
#   'neurons': 0,
#   'spectral linear discriminant analysis': 0,
#   'brain': 0,
#   'syke': 0,
#   'heart rate variability': 0,
#   'hrv': 0,
#   'cardiac cycle': 0,
#   'learning': 0,
#   'trace conditioning': 0,
#   'electroencephalography.': 0,
#   'magnetoencephalography.': 0,
#   'short-term memory.': 0,
#   'fysiologia ja neurotiede': 0,
#   'hermoverkko': 0,
#   'meg': 0,
#   'työmuisti': 0,
#   'masennus': 0,
#   'kasvontunnistus': 0,
#   'ilmeet': 0,
#   'tunteet': 0,
#   'tulkinta': 0,
#   'aivotutkimus': 0,
#   'neuropsykologia': 0,
#   'psykoterapia': 0,
#   'kognitiivinen terapia': 0,
#   'käyttäytymisterapia': 0,
#   'ryhmäterapia': 0,
#   'cbasp': 0,
#   'eye diseases': 0,
#   'facial expressions': 0,
#   'visuality': 0,
#   'recognition': 0,
#   'facial recognition': 0,
#   'age-related eye diseases': 0,
#   'bevacizumab': 0,
#   'face recognition': 0,
#   'n170': 0,
#   'ms-tauti': 0,
#   'potilaat': 0,
#   'kognitio': 0,
#   'kognitiiviset prosessit': 0,
#   'arviointi': 0,
#   'elämänlaatu': 0,
#   'heikentyminen': 0,
#   'uupumus': 0,
#   'neurofysiologia': 0,
#   'mittaus': 0,
#   'cnv': 0,
#   'p3': 0,
#   'cognition': 0,
#   'fatigue': 0,
#   'multiple sclerosis': 0,
#   'quality of life': 0,
#   'ikääntyneet': 0,
#   'kuvantaminen': 0,
#   'magneettitutkimus': 0,
#   'magnetoencephalography': 0,
#   'electroencephalography': 0,
#   'brain mapping': 0,
#   'brain diseases': 0,
#   'epilepsia': 0,
#   'hermoston taudit': 0,
#   'diagnostiikka': 0,
#   'oireet': 0,
#   'vilppula, anitta.': 0,
#   'röntgentutkimus': 0,
#   'ultraäänitutkimus': 0,
#   'tietokonetomografia': 0,
#   'liitännäistaudit': 0,
#   'uni': 0,
#   'hengitys': 0,
#   'häiriöt': 0,
#   'esiintyvyys': 0,
#   'tutkimus': 0,
#   'kyselytutkimus': 0,
#   'univaje': 0,
#   'väsymys': 0,
#   'uniapnea-oireyhtymä': 0,
#   'unihäiriöt': 0,
#   'äkkikuolema': 0,
#   'kuolleisuus': 0,
#   'hoitomenetelmät': 0,
#   'lääkehoito': 0,
#   'suomi': 0,
#   'unipolygrafia': 0,
#   'obstruktiivinen uniapnea': 0,
#   'cpap': 0,
#   'temporaaliepilepsia': 0,
#   'otsolohkoepilepsia': 0,
#   'robotit': 0,
#   'tekoäly': 0,
#   'uhkakuvat': 0,
#   'autonomiset järjestelmät': 0,
#   'keksinnöt': 0,
#   'innovaatiot': 0,
#   'ihminen-konejärjestelmät': 0,
#   'algoritmit': 0,
#   'robotiikka': 0,
#   'hakkerointi': 0,
#   'ihminen': 0,
#   'sotatekniikka': 0,
#   'manipulaatio': 0,
#   'telepatia': 0,
#   'kauko-ohjaus': 0,
#   'koneet': 0,
#   'muisti': 0,
#   'tietoturva': 0,
#   'teknologia': 0,
#   'ajatukset': 0},
#  'elektromyografia': {'mietiskely': 0,
#   'tietoinen läsnäolo': 0,
#   'eeg': 0,
#   'sanat': 0,
#   'prosessointi': 0,
#   'merkitys': 0,
#   'organisaatiot': 0,
#   'herätevaste': 0,
#   'elektromyografia': 0,
#   'korrelaatio': 0,
#   'silmänliikkeet': 0,
#   'neuroverkot': 0,
#   'emd': 0,
#   'huippukorrelaatioanalyysi': 0,
#   'responses': 0,
#   'emotions': 0,
#   'neurons': 0,
#   'spectral linear discriminant analysis': 0,
#   'brain': 0,
#   'syke': 0,
#   'heart rate variability': 0,
#   'hrv': 0,
#   'cardiac cycle': 0,
#   'learning': 0,
#   'trace conditioning': 0,
#   'electroencephalography.': 0,
#   'magnetoencephalography.': 0,
#   'short-term memory.': 0,
#   'fysiologia ja neurotiede': 0,
#   'hermoverkko': 0,
#   'meg': 0,
#   'työmuisti': 0,
#   'masennus': 0,
#   'kasvontunnistus': 0,
#   'ilmeet': 0,
#   'tunteet': 0,
#   'tulkinta': 0,
#   'aivotutkimus': 0,
#   'neuropsykologia': 0,
#   'psykoterapia': 0,
#   'kognitiivinen terapia': 0,
#   'käyttäytymisterapia': 0,
#   'ryhmäterapia': 0,
#   'cbasp': 0,
#   'eye diseases': 0,
#   'facial expressions': 0,
#   'visuality': 0,
#   'recognition': 0,
#   'facial recognition': 0,
#   'age-related eye diseases': 0,
#   'bevacizumab': 0,
#   'face recognition': 0,
#   'n170': 0,
#   'ms-tauti': 0,
#   'potilaat': 0,
#   'kognitio': 0,
#   'kognitiiviset prosessit': 0,
#   'arviointi': 0,
#   'elämänlaatu': 0,
#   'heikentyminen': 0,
#   'uupumus': 0,
#   'neurofysiologia': 0,
#   'mittaus': 0,
#   'cnv': 0,
#   'p3': 0,
#   'cognition': 0,
#   'fatigue': 0,
#   'multiple sclerosis': 0,
#   'quality of life': 0,
#   'ikääntyneet': 0,
#   'kuvantaminen': 0,
#   'magneettitutkimus': 0,
#   'magnetoencephalography': 0,
#   'electroencephalography': 0,
#   'brain mapping': 0,
#   'brain diseases': 0,
#   'epilepsia': 0,
#   'hermoston taudit': 0,
#   'diagnostiikka': 0,
#   'oireet': 0,
#   'vilppula, anitta.': 0,
#   'röntgentutkimus': 0,
#   'ultraäänitutkimus': 0,
#   'tietokonetomografia': 0,
#   'liitännäistaudit': 0,
#   'uni': 0,
#   'hengitys': 0,
#   'häiriöt': 0,
#   'esiintyvyys': 0,
#   'tutkimus': 0,
#   'kyselytutkimus': 0,
#   'univaje': 0,
#   'väsymys': 0,
#   'uniapnea-oireyhtymä': 0,
#   'unihäiriöt': 0,
#   'äkkikuolema': 0,
#   'kuolleisuus': 0,
#   'hoitomenetelmät': 0,
#   'lääkehoito': 0,
#   'suomi': 0,
#   'unipolygrafia': 0,
#   'obstruktiivinen uniapnea': 0,
#   'cpap': 0,
#   'temporaaliepilepsia': 0,
#   'otsolohkoepilepsia': 0,
#   'robotit': 0,
#   'tekoäly': 0,
#   'uhkakuvat': 0,
#   'autonomiset järjestelmät': 0,
#   'keksinnöt': 0,
#   'innovaatiot': 0,
#   'ihminen-konejärjestelmät': 0,
#   'algoritmit': 0,
#   'robotiikka': 0,
#   'hakkerointi': 0,
#   'ihminen': 0,
#   'sotatekniikka': 0,
#   'manipulaatio': 0,
#   'telepatia': 0,
#   'kauko-ohjaus': 0,
#   'koneet': 0,
#   'muisti': 0,
#   'tietoturva': 0,
#   'teknologia': 0,
#   'ajatukset': 0},
#  'korrelaatio': {'mietiskely': 0,
#   'tietoinen läsnäolo': 0,
#   'eeg': 0,
#   'sanat': 0,
#   'prosessointi': 0,
#   'merkitys': 0,
#   'organisaatiot': 0,
#   'herätevaste': 0,
#   'elektromyografia': 0,
#   'korrelaatio': 0,
#   'silmänliikkeet': 0,
#   'neuroverkot': 0,
#   'emd': 0,
#   'huippukorrelaatioanalyysi': 0,
#   'responses': 0,
#   'emotions': 0,
#   'neurons': 0,
#   'spectral linear discriminant analysis': 0,
#   'brain': 0,
#   'syke': 0,
#   'heart rate variability': 0,
#   'hrv': 0,
#   'cardiac cycle': 0,
#   'learning': 0,
#   'trace conditioning': 0,
#   'electroencephalography.': 0,
#   'magnetoencephalography.': 0,
#   'short-term memory.': 0,
#   'fysiologia ja neurotiede': 0,
#   'hermoverkko': 0,
#   'meg': 0,
#   'työmuisti': 0,
#   'masennus': 0,
#   'kasvontunnistus': 0,
#   'ilmeet': 0,
#   'tunteet': 0,
#   'tulkinta': 0,
#   'aivotutkimus': 0,
#   'neuropsykologia': 0,
#   'psykoterapia': 0,
#   'kognitiivinen terapia': 0,
#   'käyttäytymisterapia': 0,
#   'ryhmäterapia': 0,
#   'cbasp': 0,
#   'eye diseases': 0,
#   'facial expressions': 0,
#   'visuality': 0,
#   'recognition': 0,
#   'facial recognition': 0,
#   'age-related eye diseases': 0,
#   'bevacizumab': 0,
#   'face recognition': 0,
#   'n170': 0,
#   'ms-tauti': 0,
#   'potilaat': 0,
#   'kognitio': 0,
#   'kognitiiviset prosessit': 0,
#   'arviointi': 0,
#   'elämänlaatu': 0,
#   'heikentyminen': 0,
#   'uupumus': 0,
#   'neurofysiologia': 0,
#   'mittaus': 0,
#   'cnv': 0,
#   'p3': 0,
#   'cognition': 0,
#   'fatigue': 0,
#   'multiple sclerosis': 0,
#   'quality of life': 0,
#   'ikääntyneet': 0,
#   'kuvantaminen': 0,
#   'magneettitutkimus': 0,
#   'magnetoencephalography': 0,
#   'electroencephalography': 0,
#   'brain mapping': 0,
#   'brain diseases': 0,
#   'epilepsia': 0,
#   'hermoston taudit': 0,
#   'diagnostiikka': 0,
#   'oireet': 0,
#   'vilppula, anitta.': 0,
#   'röntgentutkimus': 0,
#   'ultraäänitutkimus': 0,
#   'tietokonetomografia': 0,
#   'liitännäistaudit': 0,
#   'uni': 0,
#   'hengitys': 0,
#   'häiriöt': 0,
#   'esiintyvyys': 0,
#   'tutkimus': 0,
#   'kyselytutkimus': 0,
#   'univaje': 0,
#   'väsymys': 0,
#   'uniapnea-oireyhtymä': 0,
#   'unihäiriöt': 0,
#   'äkkikuolema': 0,
#   'kuolleisuus': 0,
#   'hoitomenetelmät': 0,
#   'lääkehoito': 0,
#   'suomi': 0,
#   'unipolygrafia': 0,
#   'obstruktiivinen uniapnea': 0,
#   'cpap': 0,
#   'temporaaliepilepsia': 0,
#   'otsolohkoepilepsia': 0,
#   'robotit': 0,
#   'tekoäly': 0,
#   'uhkakuvat': 0,
#   'autonomiset järjestelmät': 0,
#   'keksinnöt': 0,
#   'innovaatiot': 0,
#   'ihminen-konejärjestelmät': 0,
#   'algoritmit': 0,
#   'robotiikka': 0,
#   'hakkerointi': 0,
#   'ihminen': 0,
#   'sotatekniikka': 0,
#   'manipulaatio': 0,
#   'telepatia': 0,
#   'kauko-ohjaus': 0,
#   'koneet': 0,
#   'muisti': 0,
#   'tietoturva': 0,
#   'teknologia': 0,
#   'ajatukset': 0},
#  'silmänliikkeet': {'mietiskely': 0,
#   'tietoinen läsnäolo': 0,
#   'eeg': 0,
#   'sanat': 0,
#   'prosessointi': 0,
#   'merkitys': 0,
#   'organisaatiot': 0,
#   'herätevaste': 0,
#   'elektromyografia': 0,
#   'korrelaatio': 0,
#   'silmänliikkeet': 0,
#   'neuroverkot': 0,
#   'emd': 0,
#   'huippukorrelaatioanalyysi': 0,
#   'responses': 0,
#   'emotions': 0,
#   'neurons': 0,
#   'spectral linear discriminant analysis': 0,
#   'brain': 0,
#   'syke': 0,
#   'heart rate variability': 0,
#   'hrv': 0,
#   'cardiac cycle': 0,
#   'learning': 0,
#   'trace conditioning': 0,
#   'electroencephalography.': 0,
#   'magnetoencephalography.': 0,
#   'short-term memory.': 0,
#   'fysiologia ja neurotiede': 0,
#   'hermoverkko': 0,
#   'meg': 0,
#   'työmuisti': 0,
#   'masennus': 0,
#   'kasvontunnistus': 0,
#   'ilmeet': 0,
#   'tunteet': 0,
#   'tulkinta': 0,
#   'aivotutkimus': 0,
#   'neuropsykologia': 0,
#   'psykoterapia': 0,
#   'kognitiivinen terapia': 0,
#   'käyttäytymisterapia': 0,
#   'ryhmäterapia': 0,
#   'cbasp': 0,
#   'eye diseases': 0,
#   'facial expressions': 0,
#   'visuality': 0,
#   'recognition': 0,
#   'facial recognition': 0,
#   'age-related eye diseases': 0,
#   'bevacizumab': 0,
#   'face recognition': 0,
#   'n170': 0,
#   'ms-tauti': 0,
#   'potilaat': 0,
#   'kognitio': 0,
#   'kognitiiviset prosessit': 0,
#   'arviointi': 0,
#   'elämänlaatu': 0,
#   'heikentyminen': 0,
#   'uupumus': 0,
#   'neurofysiologia': 0,
#   'mittaus': 0,
#   'cnv': 0,
#   'p3': 0,
#   'cognition': 0,
#   'fatigue': 0,
#   'multiple sclerosis': 0,
#   'quality of life': 0,
#   'ikääntyneet': 0,
#   'kuvantaminen': 0,
#   'magneettitutkimus': 0,
#   'magnetoencephalography': 0,
#   'electroencephalography': 0,
#   'brain mapping': 0,
#   'brain diseases': 0,
#   'epilepsia': 0,
#   'hermoston taudit': 0,
#   'diagnostiikka': 0,
#   'oireet': 0,
#   'vilppula, anitta.': 0,
#   'röntgentutkimus': 0,
#   'ultraäänitutkimus': 0,
#   'tietokonetomografia': 0,
#   'liitännäistaudit': 0,
#   'uni': 0,
#   'hengitys': 0,
#   'häiriöt': 0,
#   'esiintyvyys': 0,
#   'tutkimus': 0,
#   'kyselytutkimus': 0,
#   'univaje': 0,
#   'väsymys': 0,
#   'uniapnea-oireyhtymä': 0,
#   'unihäiriöt': 0,
#   'äkkikuolema': 0,
#   'kuolleisuus': 0,
#   'hoitomenetelmät': 0,
#   'lääkehoito': 0,
#   'suomi': 0,
#   'unipolygrafia': 0,
#   'obstruktiivinen uniapnea': 0,
#   'cpap': 0,
#   'temporaaliepilepsia': 0,
#   'otsolohkoepilepsia': 0,
#   'robotit': 0,
#   'tekoäly': 0,
#   'uhkakuvat': 0,
#   'autonomiset järjestelmät': 0,
#   'keksinnöt': 0,
#   'innovaatiot': 0,
#   'ihminen-konejärjestelmät': 0,
#   'algoritmit': 0,
#   'robotiikka': 0,
#   'hakkerointi': 0,
#   'ihminen': 0,
#   'sotatekniikka': 0,
#   'manipulaatio': 0,
#   'telepatia': 0,
#   'kauko-ohjaus': 0,
#   'koneet': 0,
#   'muisti': 0,
#   'tietoturva': 0,
#   'teknologia': 0,
#   'ajatukset': 0},
#  'neuroverkot': {'mietiskely': 0,
#   'tietoinen läsnäolo': 0,
#   'eeg': 0,
#   'sanat': 0,
#   'prosessointi': 0,
#   'merkitys': 0,
#   'organisaatiot': 0,
#   'herätevaste': 0,
#   'elektromyografia': 0,
#   'korrelaatio': 0,
#   'silmänliikkeet': 0,
#   'neuroverkot': 0,
#   'emd': 0,
#   'huippukorrelaatioanalyysi': 0,
#   'responses': 0,
#   'emotions': 0,
#   'neurons': 0,
#   'spectral linear discriminant analysis': 0,
#   'brain': 0,
#   'syke': 0,
#   'heart rate variability': 0,
#   'hrv': 0,
#   'cardiac cycle': 0,
#   'learning': 0,
#   'trace conditioning': 0,
#   'electroencephalography.': 0,
#   'magnetoencephalography.': 0,
#   'short-term memory.': 0,
#   'fysiologia ja neurotiede': 0,
#   'hermoverkko': 0,
#   'meg': 0,
#   'työmuisti': 0,
#   'masennus': 0,
#   'kasvontunnistus': 0,
#   'ilmeet': 0,
#   'tunteet': 0,
#   'tulkinta': 0,
#   'aivotutkimus': 0,
#   'neuropsykologia': 0,
#   'psykoterapia': 0,
#   'kognitiivinen terapia': 0,
#   'käyttäytymisterapia': 0,
#   'ryhmäterapia': 0,
#   'cbasp': 0,
#   'eye diseases': 0,
#   'facial expressions': 0,
#   'visuality': 0,
#   'recognition': 0,
#   'facial recognition': 0,
#   'age-related eye diseases': 0,
#   'bevacizumab': 0,
#   'face recognition': 0,
#   'n170': 0,
#   'ms-tauti': 0,
#   'potilaat': 0,
#   'kognitio': 0,
#   'kognitiiviset prosessit': 0,
#   'arviointi': 0,
#   'elämänlaatu': 0,
#   'heikentyminen': 0,
#   'uupumus': 0,
#   'neurofysiologia': 0,
#   'mittaus': 0,
#   'cnv': 0,
#   'p3': 0,
#   'cognition': 0,
#   'fatigue': 0,
#   'multiple sclerosis': 0,
#   'quality of life': 0,
#   'ikääntyneet': 0,
#   'kuvantaminen': 0,
#   'magneettitutkimus': 0,
#   'magnetoencephalography': 0,
#   'electroencephalography': 0,
#   'brain mapping': 0,
#   'brain diseases': 0,
#   'epilepsia': 0,
#   'hermoston taudit': 0,
#   'diagnostiikka': 0,
#   'oireet': 0,
#   'vilppula, anitta.': 0,
#   'röntgentutkimus': 0,
#   'ultraäänitutkimus': 0,
#   'tietokonetomografia': 0,
#   'liitännäistaudit': 0,
#   'uni': 0,
#   'hengitys': 0,
#   'häiriöt': 0,
#   'esiintyvyys': 0,
#   'tutkimus': 0,
#   'kyselytutkimus': 0,
#   'univaje': 0,
#   'väsymys': 0,
#   'uniapnea-oireyhtymä': 0,
#   'unihäiriöt': 0,
#   'äkkikuolema': 0,
#   'kuolleisuus': 0,
#   'hoitomenetelmät': 0,
#   'lääkehoito': 0,
#   'suomi': 0,
#   'unipolygrafia': 0,
#   'obstruktiivinen uniapnea': 0,
#   'cpap': 0,
#   'temporaaliepilepsia': 0,
#   'otsolohkoepilepsia': 0,
#   'robotit': 0,
#   'tekoäly': 0,
#   'uhkakuvat': 0,
#   'autonomiset järjestelmät': 0,
#   'keksinnöt': 0,
#   'innovaatiot': 0,
#   'ihminen-konejärjestelmät': 0,
#   'algoritmit': 0,
#   'robotiikka': 0,
#   'hakkerointi': 0,
#   'ihminen': 0,
#   'sotatekniikka': 0,
#   'manipulaatio': 0,
#   'telepatia': 0,
#   'kauko-ohjaus': 0,
#   'koneet': 0,
#   'muisti': 0,
#   'tietoturva': 0,
#   'teknologia': 0,
#   'ajatukset': 0},
#  'emd': {'mietiskely': 0,
#   'tietoinen läsnäolo': 0,
#   'eeg': 0,
#   'sanat': 0,
#   'prosessointi': 0,
#   'merkitys': 0,
#   'organisaatiot': 0,
#   'herätevaste': 0,
#   'elektromyografia': 0,
#   'korrelaatio': 0,
#   'silmänliikkeet': 0,
#   'neuroverkot': 0,
#   'emd': 0,
#   'huippukorrelaatioanalyysi': 0,
#   'responses': 0,
#   'emotions': 0,
#   'neurons': 0,
#   'spectral linear discriminant analysis': 0,
#   'brain': 0,
#   'syke': 0,
#   'heart rate variability': 0,
#   'hrv': 0,
#   'cardiac cycle': 0,
#   'learning': 0,
#   'trace conditioning': 0,
#   'electroencephalography.': 0,
#   'magnetoencephalography.': 0,
#   'short-term memory.': 0,
#   'fysiologia ja neurotiede': 0,
#   'hermoverkko': 0,
#   'meg': 0,
#   'työmuisti': 0,
#   'masennus': 0,
#   'kasvontunnistus': 0,
#   'ilmeet': 0,
#   'tunteet': 0,
#   'tulkinta': 0,
#   'aivotutkimus': 0,
#   'neuropsykologia': 0,
#   'psykoterapia': 0,
#   'kognitiivinen terapia': 0,
#   'käyttäytymisterapia': 0,
#   'ryhmäterapia': 0,
#   'cbasp': 0,
#   'eye diseases': 0,
#   'facial expressions': 0,
#   'visuality': 0,
#   'recognition': 0,
#   'facial recognition': 0,
#   'age-related eye diseases': 0,
#   'bevacizumab': 0,
#   'face recognition': 0,
#   'n170': 0,
#   'ms-tauti': 0,
#   'potilaat': 0,
#   'kognitio': 0,
#   'kognitiiviset prosessit': 0,
#   'arviointi': 0,
#   'elämänlaatu': 0,
#   'heikentyminen': 0,
#   'uupumus': 0,
#   'neurofysiologia': 0,
#   'mittaus': 0,
#   'cnv': 0,
#   'p3': 0,
#   'cognition': 0,
#   'fatigue': 0,
#   'multiple sclerosis': 0,
#   'quality of life': 0,
#   'ikääntyneet': 0,
#   'kuvantaminen': 0,
#   'magneettitutkimus': 0,
#   'magnetoencephalography': 0,
#   'electroencephalography': 0,
#   'brain mapping': 0,
#   'brain diseases': 0,
#   'epilepsia': 0,
#   'hermoston taudit': 0,
#   'diagnostiikka': 0,
#   'oireet': 0,
#   'vilppula, anitta.': 0,
#   'röntgentutkimus': 0,
#   'ultraäänitutkimus': 0,
#   'tietokonetomografia': 0,
#   'liitännäistaudit': 0,
#   'uni': 0,
#   'hengitys': 0,
#   'häiriöt': 0,
#   'esiintyvyys': 0,
#   'tutkimus': 0,
#   'kyselytutkimus': 0,
#   'univaje': 0,
#   'väsymys': 0,
#   'uniapnea-oireyhtymä': 0,
#   'unihäiriöt': 0,
#   'äkkikuolema': 0,
#   'kuolleisuus': 0,
#   'hoitomenetelmät': 0,
#   'lääkehoito': 0,
#   'suomi': 0,
#   'unipolygrafia': 0,
#   'obstruktiivinen uniapnea': 0,
#   'cpap': 0,
#   'temporaaliepilepsia': 0,
#   'otsolohkoepilepsia': 0,
#   'robotit': 0,
#   'tekoäly': 0,
#   'uhkakuvat': 0,
#   'autonomiset järjestelmät': 0,
#   'keksinnöt': 0,
#   'innovaatiot': 0,
#   'ihminen-konejärjestelmät': 0,
#   'algoritmit': 0,
#   'robotiikka': 0,
#   'hakkerointi': 0,
#   'ihminen': 0,
#   'sotatekniikka': 0,
#   'manipulaatio': 0,
#   'telepatia': 0,
#   'kauko-ohjaus': 0,
#   'koneet': 0,
#   'muisti': 0,
#   'tietoturva': 0,
#   'teknologia': 0,
#   'ajatukset': 0},
#  'huippukorrelaatioanalyysi': {'mietiskely': 0,
#   'tietoinen läsnäolo': 0,
#   'eeg': 0,
#   'sanat': 0,
#   'prosessointi': 0,
#   'merkitys': 0,
#   'organisaatiot': 0,
#   'herätevaste': 0,
#   'elektromyografia': 0,
#   'korrelaatio': 0,
#   'silmänliikkeet': 0,
#   'neuroverkot': 0,
#   'emd': 0,
#   'huippukorrelaatioanalyysi': 0,
#   'responses': 0,
#   'emotions': 0,
#   'neurons': 0,
#   'spectral linear discriminant analysis': 0,
#   'brain': 0,
#   'syke': 0,
#   'heart rate variability': 0,
#   'hrv': 0,
#   'cardiac cycle': 0,
#   'learning': 0,
#   'trace conditioning': 0,
#   'electroencephalography.': 0,
#   'magnetoencephalography.': 0,
#   'short-term memory.': 0,
#   'fysiologia ja neurotiede': 0,
#   'hermoverkko': 0,
#   'meg': 0,
#   'työmuisti': 0,
#   'masennus': 0,
#   'kasvontunnistus': 0,
#   'ilmeet': 0,
#   'tunteet': 0,
#   'tulkinta': 0,
#   'aivotutkimus': 0,
#   'neuropsykologia': 0,
#   'psykoterapia': 0,
#   'kognitiivinen terapia': 0,
#   'käyttäytymisterapia': 0,
#   'ryhmäterapia': 0,
#   'cbasp': 0,
#   'eye diseases': 0,
#   'facial expressions': 0,
#   'visuality': 0,
#   'recognition': 0,
#   'facial recognition': 0,
#   'age-related eye diseases': 0,
#   'bevacizumab': 0,
#   'face recognition': 0,
#   'n170': 0,
#   'ms-tauti': 0,
#   'potilaat': 0,
#   'kognitio': 0,
#   'kognitiiviset prosessit': 0,
#   'arviointi': 0,
#   'elämänlaatu': 0,
#   'heikentyminen': 0,
#   'uupumus': 0,
#   'neurofysiologia': 0,
#   'mittaus': 0,
#   'cnv': 0,
#   'p3': 0,
#   'cognition': 0,
#   'fatigue': 0,
#   'multiple sclerosis': 0,
#   'quality of life': 0,
#   'ikääntyneet': 0,
#   'kuvantaminen': 0,
#   'magneettitutkimus': 0,
#   'magnetoencephalography': 0,
#   'electroencephalography': 0,
#   'brain mapping': 0,
#   'brain diseases': 0,
#   'epilepsia': 0,
#   'hermoston taudit': 0,
#   'diagnostiikka': 0,
#   'oireet': 0,
#   'vilppula, anitta.': 0,
#   'röntgentutkimus': 0,
#   'ultraäänitutkimus': 0,
#   'tietokonetomografia': 0,
#   'liitännäistaudit': 0,
#   'uni': 0,
#   'hengitys': 0,
#   'häiriöt': 0,
#   'esiintyvyys': 0,
#   'tutkimus': 0,
#   'kyselytutkimus': 0,
#   'univaje': 0,
#   'väsymys': 0,
#   'uniapnea-oireyhtymä': 0,
#   'unihäiriöt': 0,
#   'äkkikuolema': 0,
#   'kuolleisuus': 0,
#   'hoitomenetelmät': 0,
#   'lääkehoito': 0,
#   'suomi': 0,
#   'unipolygrafia': 0,
#   'obstruktiivinen uniapnea': 0,
#   'cpap': 0,
#   'temporaaliepilepsia': 0,
#   'otsolohkoepilepsia': 0,
#   'robotit': 0,
#   'tekoäly': 0,
#   'uhkakuvat': 0,
#   'autonomiset järjestelmät': 0,
#   'keksinnöt': 0,
#   'innovaatiot': 0,
#   'ihminen-konejärjestelmät': 0,
#   'algoritmit': 0,
#   'robotiikka': 0,
#   'hakkerointi': 0,
#   'ihminen': 0,
#   'sotatekniikka': 0,
#   'manipulaatio': 0,
#   'telepatia': 0,
#   'kauko-ohjaus': 0,
#   'koneet': 0,
#   'muisti': 0,
#   'tietoturva': 0,
#   'teknologia': 0,
#   'ajatukset': 0},
#  'responses': {'mietiskely': 0,
#   'tietoinen läsnäolo': 0,
#   'eeg': 0,
#   'sanat': 0,
#   'prosessointi': 0,
#   'merkitys': 0,
#   'organisaatiot': 0,
#   'herätevaste': 0,
#   'elektromyografia': 0,
#   'korrelaatio': 0,
#   'silmänliikkeet': 0,
#   'neuroverkot': 0,
#   'emd': 0,
#   'huippukorrelaatioanalyysi': 0,
#   'responses': 0,
#   'emotions': 0,
#   'neurons': 0,
#   'spectral linear discriminant analysis': 0,
#   'brain': 0,
#   'syke': 0,
#   'heart rate variability': 0,
#   'hrv': 0,
#   'cardiac cycle': 0,
#   'learning': 0,
#   'trace conditioning': 0,
#   'electroencephalography.': 0,
#   'magnetoencephalography.': 0,
#   'short-term memory.': 0,
#   'fysiologia ja neurotiede': 0,
#   'hermoverkko': 0,
#   'meg': 0,
#   'työmuisti': 0,
#   'masennus': 0,
#   'kasvontunnistus': 0,
#   'ilmeet': 0,
#   'tunteet': 0,
#   'tulkinta': 0,
#   'aivotutkimus': 0,
#   'neuropsykologia': 0,
#   'psykoterapia': 0,
#   'kognitiivinen terapia': 0,
#   'käyttäytymisterapia': 0,
#   'ryhmäterapia': 0,
#   'cbasp': 0,
#   'eye diseases': 0,
#   'facial expressions': 0,
#   'visuality': 0,
#   'recognition': 0,
#   'facial recognition': 0,
#   'age-related eye diseases': 0,
#   'bevacizumab': 0,
#   'face recognition': 0,
#   'n170': 0,
#   'ms-tauti': 0,
#   'potilaat': 0,
#   'kognitio': 0,
#   'kognitiiviset prosessit': 0,
#   'arviointi': 0,
#   'elämänlaatu': 0,
#   'heikentyminen': 0,
#   'uupumus': 0,
#   'neurofysiologia': 0,
#   'mittaus': 0,
#   'cnv': 0,
#   'p3': 0,
#   'cognition': 0,
#   'fatigue': 0,
#   'multiple sclerosis': 0,
#   'quality of life': 0,
#   'ikääntyneet': 0,
#   'kuvantaminen': 0,
#   'magneettitutkimus': 0,
#   'magnetoencephalography': 0,
#   'electroencephalography': 0,
#   'brain mapping': 0,
#   'brain diseases': 0,
#   'epilepsia': 0,
#   'hermoston taudit': 0,
#   'diagnostiikka': 0,
#   'oireet': 0,
#   'vilppula, anitta.': 0,
#   'röntgentutkimus': 0,
#   'ultraäänitutkimus': 0,
#   'tietokonetomografia': 0,
#   'liitännäistaudit': 0,
#   'uni': 0,
#   'hengitys': 0,
#   'häiriöt': 0,
#   'esiintyvyys': 0,
#   'tutkimus': 0,
#   'kyselytutkimus': 0,
#   'univaje': 0,
#   'väsymys': 0,
#   'uniapnea-oireyhtymä': 0,
#   'unihäiriöt': 0,
#   'äkkikuolema': 0,
#   'kuolleisuus': 0,
#   'hoitomenetelmät': 0,
#   'lääkehoito': 0,
#   'suomi': 0,
#   'unipolygrafia': 0,
#   'obstruktiivinen uniapnea': 0,
#   'cpap': 0,
#   'temporaaliepilepsia': 0,
#   'otsolohkoepilepsia': 0,
#   'robotit': 0,
#   'tekoäly': 0,
#   'uhkakuvat': 0,
#   'autonomiset järjestelmät': 0,
#   'keksinnöt': 0,
#   'innovaatiot': 0,
#   'ihminen-konejärjestelmät': 0,
#   'algoritmit': 0,
#   'robotiikka': 0,
#   'hakkerointi': 0,
#   'ihminen': 0,
#   'sotatekniikka': 0,
#   'manipulaatio': 0,
#   'telepatia': 0,
#   'kauko-ohjaus': 0,
#   'koneet': 0,
#   'muisti': 0,
#   'tietoturva': 0,
#   'teknologia': 0,
#   'ajatukset': 0},
#  'emotions': {'mietiskely': 0,
#   'tietoinen läsnäolo': 0,
#   'eeg': 0,
#   'sanat': 0,
#   'prosessointi': 0,
#   'merkitys': 0,
#   'organisaatiot': 0,
#   'herätevaste': 0,
#   'elektromyografia': 0,
#   'korrelaatio': 0,
#   'silmänliikkeet': 0,
#   'neuroverkot': 0,
#   'emd': 0,
#   'huippukorrelaatioanalyysi': 0,
#   'responses': 0,
#   'emotions': 0,
#   'neurons': 0,
#   'spectral linear discriminant analysis': 0,
#   'brain': 0,
#   'syke': 0,
#   'heart rate variability': 0,
#   'hrv': 0,
#   'cardiac cycle': 0,
#   'learning': 0,
#   'trace conditioning': 0,
#   'electroencephalography.': 0,
#   'magnetoencephalography.': 0,
#   'short-term memory.': 0,
#   'fysiologia ja neurotiede': 0,
#   'hermoverkko': 0,
#   'meg': 0,
#   'työmuisti': 0,
#   'masennus': 0,
#   'kasvontunnistus': 0,
#   'ilmeet': 0,
#   'tunteet': 0,
#   'tulkinta': 0,
#   'aivotutkimus': 0,
#   'neuropsykologia': 0,
#   'psykoterapia': 0,
#   'kognitiivinen terapia': 0,
#   'käyttäytymisterapia': 0,
#   'ryhmäterapia': 0,
#   'cbasp': 0,
#   'eye diseases': 0,
#   'facial expressions': 0,
#   'visuality': 0,
#   'recognition': 0,
#   'facial recognition': 0,
#   'age-related eye diseases': 0,
#   'bevacizumab': 0,
#   'face recognition': 0,
#   'n170': 0,
#   'ms-tauti': 0,
#   'potilaat': 0,
#   'kognitio': 0,
#   'kognitiiviset prosessit': 0,
#   'arviointi': 0,
#   'elämänlaatu': 0,
#   'heikentyminen': 0,
#   'uupumus': 0,
#   'neurofysiologia': 0,
#   'mittaus': 0,
#   'cnv': 0,
#   'p3': 0,
#   'cognition': 0,
#   'fatigue': 0,
#   'multiple sclerosis': 0,
#   'quality of life': 0,
#   'ikääntyneet': 0,
#   'kuvantaminen': 0,
#   'magneettitutkimus': 0,
#   'magnetoencephalography': 0,
#   'electroencephalography': 0,
#   'brain mapping': 0,
#   'brain diseases': 0,
#   'epilepsia': 0,
#   'hermoston taudit': 0,
#   'diagnostiikka': 0,
#   'oireet': 0,
#   'vilppula, anitta.': 0,
#   'röntgentutkimus': 0,
#   'ultraäänitutkimus': 0,
#   'tietokonetomografia': 0,
#   'liitännäistaudit': 0,
#   'uni': 0,
#   'hengitys': 0,
#   'häiriöt': 0,
#   'esiintyvyys': 0,
#   'tutkimus': 0,
#   'kyselytutkimus': 0,
#   'univaje': 0,
#   'väsymys': 0,
#   'uniapnea-oireyhtymä': 0,
#   'unihäiriöt': 0,
#   'äkkikuolema': 0,
#   'kuolleisuus': 0,
#   'hoitomenetelmät': 0,
#   'lääkehoito': 0,
#   'suomi': 0,
#   'unipolygrafia': 0,
#   'obstruktiivinen uniapnea': 0,
#   'cpap': 0,
#   'temporaaliepilepsia': 0,
#   'otsolohkoepilepsia': 0,
#   'robotit': 0,
#   'tekoäly': 0,
#   'uhkakuvat': 0,
#   'autonomiset järjestelmät': 0,
#   'keksinnöt': 0,
#   'innovaatiot': 0,
#   'ihminen-konejärjestelmät': 0,
#   'algoritmit': 0,
#   'robotiikka': 0,
#   'hakkerointi': 0,
#   'ihminen': 0,
#   'sotatekniikka': 0,
#   'manipulaatio': 0,
#   'telepatia': 0,
#   'kauko-ohjaus': 0,
#   'koneet': 0,
#   'muisti': 0,
#   'tietoturva': 0,
#   'teknologia': 0,
#   'ajatukset': 0},
#  'neurons': {'mietiskely': 0,
#   'tietoinen läsnäolo': 0,
#   'eeg': 0,
#   'sanat': 0,
#   'prosessointi': 0,
#   'merkitys': 0,
#   'organisaatiot': 0,
#   'herätevaste': 0,
#   'elektromyografia': 0,
#   'korrelaatio': 0,
#   'silmänliikkeet': 0,
#   'neuroverkot': 0,
#   'emd': 0,
#   'huippukorrelaatioanalyysi': 0,
#   'responses': 0,
#   'emotions': 0,
#   'neurons': 0,
#   'spectral linear discriminant analysis': 0,
#   'brain': 0,
#   'syke': 0,
#   'heart rate variability': 0,
#   'hrv': 0,
#   'cardiac cycle': 0,
#   'learning': 0,
#   'trace conditioning': 0,
#   'electroencephalography.': 0,
#   'magnetoencephalography.': 0,
#   'short-term memory.': 0,
#   'fysiologia ja neurotiede': 0,
#   'hermoverkko': 0,
#   'meg': 0,
#   'työmuisti': 0,
#   'masennus': 0,
#   'kasvontunnistus': 0,
#   'ilmeet': 0,
#   'tunteet': 0,
#   'tulkinta': 0,
#   'aivotutkimus': 0,
#   'neuropsykologia': 0,
#   'psykoterapia': 0,
#   'kognitiivinen terapia': 0,
#   'käyttäytymisterapia': 0,
#   'ryhmäterapia': 0,
#   'cbasp': 0,
#   'eye diseases': 0,
#   'facial expressions': 0,
#   'visuality': 0,
#   'recognition': 0,
#   'facial recognition': 0,
#   'age-related eye diseases': 0,
#   'bevacizumab': 0,
#   'face recognition': 0,
#   'n170': 0,
#   'ms-tauti': 0,
#   'potilaat': 0,
#   'kognitio': 0,
#   'kognitiiviset prosessit': 0,
#   'arviointi': 0,
#   'elämänlaatu': 0,
#   'heikentyminen': 0,
#   'uupumus': 0,
#   'neurofysiologia': 0,
#   'mittaus': 0,
#   'cnv': 0,
#   'p3': 0,
#   'cognition': 0,
#   'fatigue': 0,
#   'multiple sclerosis': 0,
#   'quality of life': 0,
#   'ikääntyneet': 0,
#   'kuvantaminen': 0,
#   'magneettitutkimus': 0,
#   'magnetoencephalography': 0,
#   'electroencephalography': 0,
#   'brain mapping': 0,
#   'brain diseases': 0,
#   'epilepsia': 0,
#   'hermoston taudit': 0,
#   'diagnostiikka': 0,
#   'oireet': 0,
#   'vilppula, anitta.': 0,
#   'röntgentutkimus': 0,
#   'ultraäänitutkimus': 0,
#   'tietokonetomografia': 0,
#   'liitännäistaudit': 0,
#   'uni': 0,
#   'hengitys': 0,
#   'häiriöt': 0,
#   'esiintyvyys': 0,
#   'tutkimus': 0,
#   'kyselytutkimus': 0,
#   'univaje': 0,
#   'väsymys': 0,
#   'uniapnea-oireyhtymä': 0,
#   'unihäiriöt': 0,
#   'äkkikuolema': 0,
#   'kuolleisuus': 0,
#   'hoitomenetelmät': 0,
#   'lääkehoito': 0,
#   'suomi': 0,
#   'unipolygrafia': 0,
#   'obstruktiivinen uniapnea': 0,
#   'cpap': 0,
#   'temporaaliepilepsia': 0,
#   'otsolohkoepilepsia': 0,
#   'robotit': 0,
#   'tekoäly': 0,
#   'uhkakuvat': 0,
#   'autonomiset järjestelmät': 0,
#   'keksinnöt': 0,
#   'innovaatiot': 0,
#   'ihminen-konejärjestelmät': 0,
#   'algoritmit': 0,
#   'robotiikka': 0,
#   'hakkerointi': 0,
#   'ihminen': 0,
#   'sotatekniikka': 0,
#   'manipulaatio': 0,
#   'telepatia': 0,
#   'kauko-ohjaus': 0,
#   'koneet': 0,
#   'muisti': 0,
#   'tietoturva': 0,
#   'teknologia': 0,
#   'ajatukset': 0},
#  'spectral linear discriminant analysis': {'mietiskely': 0,
#   'tietoinen läsnäolo': 0,
#   'eeg': 0,
#   'sanat': 0,
#   'prosessointi': 0,
#   'merkitys': 0,
#   'organisaatiot': 0,
#   'herätevaste': 0,
#   'elektromyografia': 0,
#   'korrelaatio': 0,
#   'silmänliikkeet': 0,
#   'neuroverkot': 0,
#   'emd': 0,
#   'huippukorrelaatioanalyysi': 0,
#   'responses': 0,
#   'emotions': 0,
#   'neurons': 0,
#   'spectral linear discriminant analysis': 0,
#   'brain': 0,
#   'syke': 0,
#   'heart rate variability': 0,
#   'hrv': 0,
#   'cardiac cycle': 0,
#   'learning': 0,
#   'trace conditioning': 0,
#   'electroencephalography.': 0,
#   'magnetoencephalography.': 0,
#   'short-term memory.': 0,
#   'fysiologia ja neurotiede': 0,
#   'hermoverkko': 0,
#   'meg': 0,
#   'työmuisti': 0,
#   'masennus': 0,
#   'kasvontunnistus': 0,
#   'ilmeet': 0,
#   'tunteet': 0,
#   'tulkinta': 0,
#   'aivotutkimus': 0,
#   'neuropsykologia': 0,
#   'psykoterapia': 0,
#   'kognitiivinen terapia': 0,
#   'käyttäytymisterapia': 0,
#   'ryhmäterapia': 0,
#   'cbasp': 0,
#   'eye diseases': 0,
#   'facial expressions': 0,
#   'visuality': 0,
#   'recognition': 0,
#   'facial recognition': 0,
#   'age-related eye diseases': 0,
#   'bevacizumab': 0,
#   'face recognition': 0,
#   'n170': 0,
#   'ms-tauti': 0,
#   'potilaat': 0,
#   'kognitio': 0,
#   'kognitiiviset prosessit': 0,
#   'arviointi': 0,
#   'elämänlaatu': 0,
#   'heikentyminen': 0,
#   'uupumus': 0,
#   'neurofysiologia': 0,
#   'mittaus': 0,
#   'cnv': 0,
#   'p3': 0,
#   'cognition': 0,
#   'fatigue': 0,
#   'multiple sclerosis': 0,
#   'quality of life': 0,
#   'ikääntyneet': 0,
#   'kuvantaminen': 0,
#   'magneettitutkimus': 0,
#   'magnetoencephalography': 0,
#   'electroencephalography': 0,
#   'brain mapping': 0,
#   'brain diseases': 0,
#   'epilepsia': 0,
#   'hermoston taudit': 0,
#   'diagnostiikka': 0,
#   'oireet': 0,
#   'vilppula, anitta.': 0,
#   'röntgentutkimus': 0,
#   'ultraäänitutkimus': 0,
#   'tietokonetomografia': 0,
#   'liitännäistaudit': 0,
#   'uni': 0,
#   'hengitys': 0,
#   'häiriöt': 0,
#   'esiintyvyys': 0,
#   'tutkimus': 0,
#   'kyselytutkimus': 0,
#   'univaje': 0,
#   'väsymys': 0,
#   'uniapnea-oireyhtymä': 0,
#   'unihäiriöt': 0,
#   'äkkikuolema': 0,
#   'kuolleisuus': 0,
#   'hoitomenetelmät': 0,
#   'lääkehoito': 0,
#   'suomi': 0,
#   'unipolygrafia': 0,
#   'obstruktiivinen uniapnea': 0,
#   'cpap': 0,
#   'temporaaliepilepsia': 0,
#   'otsolohkoepilepsia': 0,
#   'robotit': 0,
#   'tekoäly': 0,
#   'uhkakuvat': 0,
#   'autonomiset järjestelmät': 0,
#   'keksinnöt': 0,
#   'innovaatiot': 0,
#   'ihminen-konejärjestelmät': 0,
#   'algoritmit': 0,
#   'robotiikka': 0,
#   'hakkerointi': 0,
#   'ihminen': 0,
#   'sotatekniikka': 0,
#   'manipulaatio': 0,
#   'telepatia': 0,
#   'kauko-ohjaus': 0,
#   'koneet': 0,
#   'muisti': 0,
#   'tietoturva': 0,
#   'teknologia': 0,
#   'ajatukset': 0},
#  'brain': {'mietiskely': 0,
#   'tietoinen läsnäolo': 0,
#   'eeg': 0,
#   'sanat': 0,
#   'prosessointi': 0,
#   'merkitys': 0,
#   'organisaatiot': 0,
#   'herätevaste': 0,
#   'elektromyografia': 0,
#   'korrelaatio': 0,
#   'silmänliikkeet': 0,
#   'neuroverkot': 0,
# ...
#   'koneet': 0,
#   'muisti': 0,
#   'tietoturva': 0,
#   'teknologia': 0,
#   'ajatukset': 0},
#  'kauko-ohjaus': {'mietiskely': 0,
#   'tietoinen läsnäolo': 0,
#   'eeg': 0,
#   'sanat': 0,
#   'prosessointi': 0,
#   'merkitys': 0,
#   'organisaatiot': 0,
#   'herätevaste': 0,
#   'elektromyografia': 0,
#   'korrelaatio': 0,
#   'silmänliikkeet': 0,
#   'neuroverkot': 0,
#   'emd': 0,
#   'huippukorrelaatioanalyysi': 0,
#   'responses': 0,
#   'emotions': 0,
#   'neurons': 0,
#   'spectral linear discriminant analysis': 0,
#   'brain': 0,
#   'syke': 0,
#   'heart rate variability': 0,
#   'hrv': 0,
#   'cardiac cycle': 0,
#   'learning': 0,
#   'trace conditioning': 0,
#   'electroencephalography.': 0,
#   'magnetoencephalography.': 0,
#   'short-term memory.': 0,
#   'fysiologia ja neurotiede': 0,
#   'hermoverkko': 0,
#   'meg': 0,
#   'työmuisti': 0,
#   'masennus': 0,
#   'kasvontunnistus': 0,
#   'ilmeet': 0,
#   'tunteet': 0,
#   'tulkinta': 0,
#   'aivotutkimus': 0,
#   'neuropsykologia': 0,
#   'psykoterapia': 0,
#   'kognitiivinen terapia': 0,
#   'käyttäytymisterapia': 0,
#   'ryhmäterapia': 0,
#   'cbasp': 0,
#   'eye diseases': 0,
#   'facial expressions': 0,
#   'visuality': 0,
#   'recognition': 0,
#   'facial recognition': 0,
#   'age-related eye diseases': 0,
#   'bevacizumab': 0,
#   'face recognition': 0,
#   'n170': 0,
#   'ms-tauti': 0,
#   'potilaat': 0,
#   'kognitio': 0,
#   'kognitiiviset prosessit': 0,
#   'arviointi': 0,
#   'elämänlaatu': 0,
#   'heikentyminen': 0,
#   'uupumus': 0,
#   'neurofysiologia': 0,
#   'mittaus': 0,
#   'cnv': 0,
#   'p3': 0,
#   'cognition': 0,
#   'fatigue': 0,
#   'multiple sclerosis': 0,
#   'quality of life': 0,
#   'ikääntyneet': 0,
#   'kuvantaminen': 0,
#   'magneettitutkimus': 0,
#   'magnetoencephalography': 0,
#   'electroencephalography': 0,
#   'brain mapping': 0,
#   'brain diseases': 0,
#   'epilepsia': 0,
#   'hermoston taudit': 0,
#   'diagnostiikka': 0,
#   'oireet': 0,
#   'vilppula, anitta.': 0,
#   'röntgentutkimus': 0,
#   'ultraäänitutkimus': 0,
#   'tietokonetomografia': 0,
#   'liitännäistaudit': 0,
#   'uni': 0,
#   'hengitys': 0,
#   'häiriöt': 0,
#   'esiintyvyys': 0,
#   'tutkimus': 0,
#   'kyselytutkimus': 0,
#   'univaje': 0,
#   'väsymys': 0,
#   'uniapnea-oireyhtymä': 0,
#   'unihäiriöt': 0,
#   'äkkikuolema': 0,
#   'kuolleisuus': 0,
#   'hoitomenetelmät': 0,
#   'lääkehoito': 0,
#   'suomi': 0,
#   'unipolygrafia': 0,
#   'obstruktiivinen uniapnea': 0,
#   'cpap': 0,
#   'temporaaliepilepsia': 0,
#   'otsolohkoepilepsia': 0,
#   'robotit': 0,
#   'tekoäly': 0,
#   'uhkakuvat': 0,
#   'autonomiset järjestelmät': 0,
#   'keksinnöt': 0,
#   'innovaatiot': 0,
#   'ihminen-konejärjestelmät': 0,
#   'algoritmit': 0,
#   'robotiikka': 0,
#   'hakkerointi': 0,
#   'ihminen': 0,
#   'sotatekniikka': 0,
#   'manipulaatio': 0,
#   'telepatia': 0,
#   'kauko-ohjaus': 0,
#   'koneet': 0,
#   'muisti': 0,
#   'tietoturva': 0,
#   'teknologia': 0,
#   'ajatukset': 0},
#  'koneet': {'mietiskely': 0,
#   'tietoinen läsnäolo': 0,
#   'eeg': 0,
#   'sanat': 0,
#   'prosessointi': 0,
#   'merkitys': 0,
#   'organisaatiot': 0,
#   'herätevaste': 0,
#   'elektromyografia': 0,
#   'korrelaatio': 0,
#   'silmänliikkeet': 0,
#   'neuroverkot': 0,
#   'emd': 0,
#   'huippukorrelaatioanalyysi': 0,
#   'responses': 0,
#   'emotions': 0,
#   'neurons': 0,
#   'spectral linear discriminant analysis': 0,
#   'brain': 0,
#   'syke': 0,
#   'heart rate variability': 0,
#   'hrv': 0,
#   'cardiac cycle': 0,
#   'learning': 0,
#   'trace conditioning': 0,
#   'electroencephalography.': 0,
#   'magnetoencephalography.': 0,
#   'short-term memory.': 0,
#   'fysiologia ja neurotiede': 0,
#   'hermoverkko': 0,
#   'meg': 0,
#   'työmuisti': 0,
#   'masennus': 0,
#   'kasvontunnistus': 0,
#   'ilmeet': 0,
#   'tunteet': 0,
#   'tulkinta': 0,
#   'aivotutkimus': 0,
#   'neuropsykologia': 0,
#   'psykoterapia': 0,
#   'kognitiivinen terapia': 0,
#   'käyttäytymisterapia': 0,
#   'ryhmäterapia': 0,
#   'cbasp': 0,
#   'eye diseases': 0,
#   'facial expressions': 0,
#   'visuality': 0,
#   'recognition': 0,
#   'facial recognition': 0,
#   'age-related eye diseases': 0,
#   'bevacizumab': 0,
#   'face recognition': 0,
#   'n170': 0,
#   'ms-tauti': 0,
#   'potilaat': 0,
#   'kognitio': 0,
#   'kognitiiviset prosessit': 0,
#   'arviointi': 0,
#   'elämänlaatu': 0,
#   'heikentyminen': 0,
#   'uupumus': 0,
#   'neurofysiologia': 0,
#   'mittaus': 0,
#   'cnv': 0,
#   'p3': 0,
#   'cognition': 0,
#   'fatigue': 0,
#   'multiple sclerosis': 0,
#   'quality of life': 0,
#   'ikääntyneet': 0,
#   'kuvantaminen': 0,
#   'magneettitutkimus': 0,
#   'magnetoencephalography': 0,
#   'electroencephalography': 0,
#   'brain mapping': 0,
#   'brain diseases': 0,
#   'epilepsia': 0,
#   'hermoston taudit': 0,
#   'diagnostiikka': 0,
#   'oireet': 0,
#   'vilppula, anitta.': 0,
#   'röntgentutkimus': 0,
#   'ultraäänitutkimus': 0,
#   'tietokonetomografia': 0,
#   'liitännäistaudit': 0,
#   'uni': 0,
#   'hengitys': 0,
#   'häiriöt': 0,
#   'esiintyvyys': 0,
#   'tutkimus': 0,
#   'kyselytutkimus': 0,
#   'univaje': 0,
#   'väsymys': 0,
#   'uniapnea-oireyhtymä': 0,
#   'unihäiriöt': 0,
#   'äkkikuolema': 0,
#   'kuolleisuus': 0,
#   'hoitomenetelmät': 0,
#   'lääkehoito': 0,
#   'suomi': 0,
#   'unipolygrafia': 0,
#   'obstruktiivinen uniapnea': 0,
#   'cpap': 0,
#   'temporaaliepilepsia': 0,
#   'otsolohkoepilepsia': 0,
#   'robotit': 0,
#   'tekoäly': 0,
#   'uhkakuvat': 0,
#   'autonomiset järjestelmät': 0,
#   'keksinnöt': 0,
#   'innovaatiot': 0,
#   'ihminen-konejärjestelmät': 0,
#   'algoritmit': 0,
#   'robotiikka': 0,
#   'hakkerointi': 0,
#   'ihminen': 0,
#   'sotatekniikka': 0,
#   'manipulaatio': 0,
#   'telepatia': 0,
#   'kauko-ohjaus': 0,
#   'koneet': 0,
#   'muisti': 0,
#   'tietoturva': 0,
#   'teknologia': 0,
#   'ajatukset': 0},
#  'muisti': {'mietiskely': 0,
#   'tietoinen läsnäolo': 0,
#   'eeg': 0,
#   'sanat': 0,
#   'prosessointi': 0,
#   'merkitys': 0,
#   'organisaatiot': 0,
#   'herätevaste': 0,
#   'elektromyografia': 0,
#   'korrelaatio': 0,
#   'silmänliikkeet': 0,
#   'neuroverkot': 0,
#   'emd': 0,
#   'huippukorrelaatioanalyysi': 0,
#   'responses': 0,
#   'emotions': 0,
#   'neurons': 0,
#   'spectral linear discriminant analysis': 0,
#   'brain': 0,
#   'syke': 0,
#   'heart rate variability': 0,
#   'hrv': 0,
#   'cardiac cycle': 0,
#   'learning': 0,
#   'trace conditioning': 0,
#   'electroencephalography.': 0,
#   'magnetoencephalography.': 0,
#   'short-term memory.': 0,
#   'fysiologia ja neurotiede': 0,
#   'hermoverkko': 0,
#   'meg': 0,
#   'työmuisti': 0,
#   'masennus': 0,
#   'kasvontunnistus': 0,
#   'ilmeet': 0,
#   'tunteet': 0,
#   'tulkinta': 0,
#   'aivotutkimus': 0,
#   'neuropsykologia': 0,
#   'psykoterapia': 0,
#   'kognitiivinen terapia': 0,
#   'käyttäytymisterapia': 0,
#   'ryhmäterapia': 0,
#   'cbasp': 0,
#   'eye diseases': 0,
#   'facial expressions': 0,
#   'visuality': 0,
#   'recognition': 0,
#   'facial recognition': 0,
#   'age-related eye diseases': 0,
#   'bevacizumab': 0,
#   'face recognition': 0,
#   'n170': 0,
#   'ms-tauti': 0,
#   'potilaat': 0,
#   'kognitio': 0,
#   'kognitiiviset prosessit': 0,
#   'arviointi': 0,
#   'elämänlaatu': 0,
#   'heikentyminen': 0,
#   'uupumus': 0,
#   'neurofysiologia': 0,
#   'mittaus': 0,
#   'cnv': 0,
#   'p3': 0,
#   'cognition': 0,
#   'fatigue': 0,
#   'multiple sclerosis': 0,
#   'quality of life': 0,
#   'ikääntyneet': 0,
#   'kuvantaminen': 0,
#   'magneettitutkimus': 0,
#   'magnetoencephalography': 0,
#   'electroencephalography': 0,
#   'brain mapping': 0,
#   'brain diseases': 0,
#   'epilepsia': 0,
#   'hermoston taudit': 0,
#   'diagnostiikka': 0,
#   'oireet': 0,
#   'vilppula, anitta.': 0,
#   'röntgentutkimus': 0,
#   'ultraäänitutkimus': 0,
#   'tietokonetomografia': 0,
#   'liitännäistaudit': 0,
#   'uni': 0,
#   'hengitys': 0,
#   'häiriöt': 0,
#   'esiintyvyys': 0,
#   'tutkimus': 0,
#   'kyselytutkimus': 0,
#   'univaje': 0,
#   'väsymys': 0,
#   'uniapnea-oireyhtymä': 0,
#   'unihäiriöt': 0,
#   'äkkikuolema': 0,
#   'kuolleisuus': 0,
#   'hoitomenetelmät': 0,
#   'lääkehoito': 0,
#   'suomi': 0,
#   'unipolygrafia': 0,
#   'obstruktiivinen uniapnea': 0,
#   'cpap': 0,
#   'temporaaliepilepsia': 0,
#   'otsolohkoepilepsia': 0,
#   'robotit': 0,
#   'tekoäly': 0,
#   'uhkakuvat': 0,
#   'autonomiset järjestelmät': 0,
#   'keksinnöt': 0,
#   'innovaatiot': 0,
#   'ihminen-konejärjestelmät': 0,
#   'algoritmit': 0,
#   'robotiikka': 0,
#   'hakkerointi': 0,
#   'ihminen': 0,
#   'sotatekniikka': 0,
#   'manipulaatio': 0,
#   'telepatia': 0,
#   'kauko-ohjaus': 0,
#   'koneet': 0,
#   'muisti': 0,
#   'tietoturva': 0,
#   'teknologia': 0,
#   'ajatukset': 0},
#  'tietoturva': {'mietiskely': 0,
#   'tietoinen läsnäolo': 0,
#   'eeg': 0,
#   'sanat': 0,
#   'prosessointi': 0,
#   'merkitys': 0,
#   'organisaatiot': 0,
#   'herätevaste': 0,
#   'elektromyografia': 0,
#   'korrelaatio': 0,
#   'silmänliikkeet': 0,
#   'neuroverkot': 0,
#   'emd': 0,
#   'huippukorrelaatioanalyysi': 0,
#   'responses': 0,
#   'emotions': 0,
#   'neurons': 0,
#   'spectral linear discriminant analysis': 0,
#   'brain': 0,
#   'syke': 0,
#   'heart rate variability': 0,
#   'hrv': 0,
#   'cardiac cycle': 0,
#   'learning': 0,
#   'trace conditioning': 0,
#   'electroencephalography.': 0,
#   'magnetoencephalography.': 0,
#   'short-term memory.': 0,
#   'fysiologia ja neurotiede': 0,
#   'hermoverkko': 0,
#   'meg': 0,
#   'työmuisti': 0,
#   'masennus': 0,
#   'kasvontunnistus': 0,
#   'ilmeet': 0,
#   'tunteet': 0,
#   'tulkinta': 0,
#   'aivotutkimus': 0,
#   'neuropsykologia': 0,
#   'psykoterapia': 0,
#   'kognitiivinen terapia': 0,
#   'käyttäytymisterapia': 0,
#   'ryhmäterapia': 0,
#   'cbasp': 0,
#   'eye diseases': 0,
#   'facial expressions': 0,
#   'visuality': 0,
#   'recognition': 0,
#   'facial recognition': 0,
#   'age-related eye diseases': 0,
#   'bevacizumab': 0,
#   'face recognition': 0,
#   'n170': 0,
#   'ms-tauti': 0,
#   'potilaat': 0,
#   'kognitio': 0,
#   'kognitiiviset prosessit': 0,
#   'arviointi': 0,
#   'elämänlaatu': 0,
#   'heikentyminen': 0,
#   'uupumus': 0,
#   'neurofysiologia': 0,
#   'mittaus': 0,
#   'cnv': 0,
#   'p3': 0,
#   'cognition': 0,
#   'fatigue': 0,
#   'multiple sclerosis': 0,
#   'quality of life': 0,
#   'ikääntyneet': 0,
#   'kuvantaminen': 0,
#   'magneettitutkimus': 0,
#   'magnetoencephalography': 0,
#   'electroencephalography': 0,
#   'brain mapping': 0,
#   'brain diseases': 0,
#   'epilepsia': 0,
#   'hermoston taudit': 0,
#   'diagnostiikka': 0,
#   'oireet': 0,
#   'vilppula, anitta.': 0,
#   'röntgentutkimus': 0,
#   'ultraäänitutkimus': 0,
#   'tietokonetomografia': 0,
#   'liitännäistaudit': 0,
#   'uni': 0,
#   'hengitys': 0,
#   'häiriöt': 0,
#   'esiintyvyys': 0,
#   'tutkimus': 0,
#   'kyselytutkimus': 0,
#   'univaje': 0,
#   'väsymys': 0,
#   'uniapnea-oireyhtymä': 0,
#   'unihäiriöt': 0,
#   'äkkikuolema': 0,
#   'kuolleisuus': 0,
#   'hoitomenetelmät': 0,
#   'lääkehoito': 0,
#   'suomi': 0,
#   'unipolygrafia': 0,
#   'obstruktiivinen uniapnea': 0,
#   'cpap': 0,
#   'temporaaliepilepsia': 0,
#   'otsolohkoepilepsia': 0,
#   'robotit': 0,
#   'tekoäly': 0,
#   'uhkakuvat': 0,
#   'autonomiset järjestelmät': 0,
#   'keksinnöt': 0,
#   'innovaatiot': 0,
#   'ihminen-konejärjestelmät': 0,
#   'algoritmit': 0,
#   'robotiikka': 0,
#   'hakkerointi': 0,
#   'ihminen': 0,
#   'sotatekniikka': 0,
#   'manipulaatio': 0,
#   'telepatia': 0,
#   'kauko-ohjaus': 0,
#   'koneet': 0,
#   'muisti': 0,
#   'tietoturva': 0,
#   'teknologia': 0,
#   'ajatukset': 0},
#  'teknologia': {'mietiskely': 0,
#   'tietoinen läsnäolo': 0,
#   'eeg': 0,
#   'sanat': 0,
#   'prosessointi': 0,
#   'merkitys': 0,
#   'organisaatiot': 0,
#   'herätevaste': 0,
#   'elektromyografia': 0,
#   'korrelaatio': 0,
#   'silmänliikkeet': 0,
#   'neuroverkot': 0,
#   'emd': 0,
#   'huippukorrelaatioanalyysi': 0,
#   'responses': 0,
#   'emotions': 0,
#   'neurons': 0,
#   'spectral linear discriminant analysis': 0,
#   'brain': 0,
#   'syke': 0,
#   'heart rate variability': 0,
#   'hrv': 0,
#   'cardiac cycle': 0,
#   'learning': 0,
#   'trace conditioning': 0,
#   'electroencephalography.': 0,
#   'magnetoencephalography.': 0,
#   'short-term memory.': 0,
#   'fysiologia ja neurotiede': 0,
#   'hermoverkko': 0,
#   'meg': 0,
#   'työmuisti': 0,
#   'masennus': 0,
#   'kasvontunnistus': 0,
#   'ilmeet': 0,
#   'tunteet': 0,
#   'tulkinta': 0,
#   'aivotutkimus': 0,
#   'neuropsykologia': 0,
#   'psykoterapia': 0,
#   'kognitiivinen terapia': 0,
#   'käyttäytymisterapia': 0,
#   'ryhmäterapia': 0,
#   'cbasp': 0,
#   'eye diseases': 0,
#   'facial expressions': 0,
#   'visuality': 0,
#   'recognition': 0,
#   'facial recognition': 0,
#   'age-related eye diseases': 0,
#   'bevacizumab': 0,
#   'face recognition': 0,
#   'n170': 0,
#   'ms-tauti': 0,
#   'potilaat': 0,
#   'kognitio': 0,
#   'kognitiiviset prosessit': 0,
#   'arviointi': 0,
#   'elämänlaatu': 0,
#   'heikentyminen': 0,
#   'uupumus': 0,
#   'neurofysiologia': 0,
#   'mittaus': 0,
#   'cnv': 0,
#   'p3': 0,
#   'cognition': 0,
#   'fatigue': 0,
#   'multiple sclerosis': 0,
#   'quality of life': 0,
#   'ikääntyneet': 0,
#   'kuvantaminen': 0,
#   'magneettitutkimus': 0,
#   'magnetoencephalography': 0,
#   'electroencephalography': 0,
#   'brain mapping': 0,
#   'brain diseases': 0,
#   'epilepsia': 0,
#   'hermoston taudit': 0,
#   'diagnostiikka': 0,
#   'oireet': 0,
#   'vilppula, anitta.': 0,
#   'röntgentutkimus': 0,
#   'ultraäänitutkimus': 0,
#   'tietokonetomografia': 0,
#   'liitännäistaudit': 0,
#   'uni': 0,
#   'hengitys': 0,
#   'häiriöt': 0,
#   'esiintyvyys': 0,
#   'tutkimus': 0,
#   'kyselytutkimus': 0,
#   'univaje': 0,
#   'väsymys': 0,
#   'uniapnea-oireyhtymä': 0,
#   'unihäiriöt': 0,
#   'äkkikuolema': 0,
#   'kuolleisuus': 0,
#   'hoitomenetelmät': 0,
#   'lääkehoito': 0,
#   'suomi': 0,
#   'unipolygrafia': 0,
#   'obstruktiivinen uniapnea': 0,
#   'cpap': 0,
#   'temporaaliepilepsia': 0,
#   'otsolohkoepilepsia': 0,
#   'robotit': 0,
#   'tekoäly': 0,
#   'uhkakuvat': 0,
#   'autonomiset järjestelmät': 0,
#   'keksinnöt': 0,
#   'innovaatiot': 0,
#   'ihminen-konejärjestelmät': 0,
#   'algoritmit': 0,
#   'robotiikka': 0,
#   'hakkerointi': 0,
#   'ihminen': 0,
#   'sotatekniikka': 0,
#   'manipulaatio': 0,
#   'telepatia': 0,
#   'kauko-ohjaus': 0,
#   'koneet': 0,
#   'muisti': 0,
#   'tietoturva': 0,
#   'teknologia': 0,
#   'ajatukset': 0},
#  'ajatukset': {'mietiskely': 0,
#   'tietoinen läsnäolo': 0,
#   'eeg': 0,
#   'sanat': 0,
#   'prosessointi': 0,
#   'merkitys': 0,
#   'organisaatiot': 0,
#   'herätevaste': 0,
#   'elektromyografia': 0,
#   'korrelaatio': 0,
#   'silmänliikkeet': 0,
#   'neuroverkot': 0,
#   'emd': 0,
#   'huippukorrelaatioanalyysi': 0,
#   'responses': 0,
#   'emotions': 0,
#   'neurons': 0,
#   'spectral linear discriminant analysis': 0,
#   'brain': 0,
#   'syke': 0,
#   'heart rate variability': 0,
#   'hrv': 0,
#   'cardiac cycle': 0,
#   'learning': 0,
#   'trace conditioning': 0,
#   'electroencephalography.': 0,
#   'magnetoencephalography.': 0,
#   'short-term memory.': 0,
#   'fysiologia ja neurotiede': 0,
#   'hermoverkko': 0,
#   'meg': 0,
#   'työmuisti': 0,
#   'masennus': 0,
#   'kasvontunnistus': 0,
#   'ilmeet': 0,
#   'tunteet': 0,
#   'tulkinta': 0,
#   'aivotutkimus': 0,
#   'neuropsykologia': 0,
#   'psykoterapia': 0,
#   'kognitiivinen terapia': 0,
#   'käyttäytymisterapia': 0,
#   'ryhmäterapia': 0,
#   'cbasp': 0,
#   'eye diseases': 0,
#   'facial expressions': 0,
#   'visuality': 0,
#   'recognition': 0,
#   'facial recognition': 0,
#   'age-related eye diseases': 0,
#   'bevacizumab': 0,
#   'face recognition': 0,
#   'n170': 0,
#   'ms-tauti': 0,
#   'potilaat': 0,
#   'kognitio': 0,
#   'kognitiiviset prosessit': 0,
#   'arviointi': 0,
#   'elämänlaatu': 0,
#   'heikentyminen': 0,
#   'uupumus': 0,
#   'neurofysiologia': 0,
#   'mittaus': 0,
#   'cnv': 0,
#   'p3': 0,
#   'cognition': 0,
#   'fatigue': 0,
#   'multiple sclerosis': 0,
#   'quality of life': 0,
#   'ikääntyneet': 0,
#   'kuvantaminen': 0,
#   'magneettitutkimus': 0,
#   'magnetoencephalography': 0,
#   'electroencephalography': 0,
#   'brain mapping': 0,
#   'brain diseases': 0,
#   'epilepsia': 0,
#   'hermoston taudit': 0,
#   'diagnostiikka': 0,
#   'oireet': 0,
#   'vilppula, anitta.': 0,
#   'röntgentutkimus': 0,
#   'ultraäänitutkimus': 0,
#   'tietokonetomografia': 0,
#   'liitännäistaudit': 0,
#   'uni': 0,
#   'hengitys': 0,
#   'häiriöt': 0,
#   'esiintyvyys': 0,
#   'tutkimus': 0,
#   'kyselytutkimus': 0,
#   'univaje': 0,
#   'väsymys': 0,
#   'uniapnea-oireyhtymä': 0,
#   'unihäiriöt': 0,
#   'äkkikuolema': 0,
#   'kuolleisuus': 0,
#   'hoitomenetelmät': 0,
#   'lääkehoito': 0,
#   'suomi': 0,
#   'unipolygrafia': 0,
#   'obstruktiivinen uniapnea': 0,
#   'cpap': 0,
#   'temporaaliepilepsia': 0,
#   'otsolohkoepilepsia': 0,
#   'robotit': 0,
#   'tekoäly': 0,
#   'uhkakuvat': 0,
#   'autonomiset järjestelmät': 0,
#   'keksinnöt': 0,
#   'innovaatiot': 0,
#   'ihminen-konejärjestelmät': 0,
#   'algoritmit': 0,
#   'robotiikka': 0,
#   'hakkerointi': 0,
#   'ihminen': 0,
#   'sotatekniikka': 0,
#   'manipulaatio': 0,
#   'telepatia': 0,
#   'kauko-ohjaus': 0,
#   'koneet': 0,
#   'muisti': 0,
#   'tietoturva': 0,
#   'teknologia': 0,
#   'ajatukset': 0}}

# %%
#Return cooccurence matrix with keys (dict type)
def count_subjects_presented_together_one_publishcation(records, subjects_count):
    subjects_presented_together_count = {key: {key:0 for key in subjects_count.keys()} for key in subjects_count.keys() }
    for record in records:
        for subject in record['subjects']:
            for subject_ in record['subjects']:
                subjects_presented_together_count[subject.lower()][subject_.lower()] += 1
            
    return subjects_presented_together_count 

cooccurence_with_keys = count_subjects_presented_together_one_publishcation(result['records'], subjects_count)

# %%
#Return a matrix len(subjects_count) x len(subjects_count)
def cooccurence_matrix(cooccurence_with_keys):
    cooc_matrix = []
    for y in cooccurence_with_keys: 
        x_tmp = [] 
        for x in cooccurence_with_keys[y]: 
            x_tmp.append(cooccurence_with_keys[y][x])
        cooc_matrix.append(x_tmp)
    return cooc_matrix

cooc_matrix = cooccurence_matrix(cooccurence_with_keys)

# %%
result = get_and_beautify_data_from_api(lookfor="lidar", year="2015")
orgs_count = count_orgs(result['records'])#for bubble chart 
subjects_count = count_subjects(result['records'])
cooccurence_with_keys = count_subjects_presented_together_one_publishcation(result['records'], subjects_count)  
cooc_matrix = cooccurence_matrix(cooccurence_with_keys)#For heatmap chart
print("Organizations: {}\nRelated subjects: {}".format(orgs_count, list(subjects_count.keys())))
# Out:
# Organizations: {'Kansalliskirjasto': 1, 'Itä-Suomen yliopisto': 1}
# Related subjects: ['metsäpinta-ala', 'trooppiset metsät', 'forests', 'area', 'canopy', 'cartography', 'vegetation index', 'satellite imagery', 'lidar', 'regression analysis', 'mathematical models', 'forest mensuration', 'international forest definition', 'alos avnir-2', 'beta regression', 'logistic regression', 'estimation', 'technology & engineering / remote sensing & geographic information systems.', 'remote sensing.', 'tutkimussatelliitit', 'lämpökuvaus', 'spektroskopia', 'kaukokartoitus', 'kartoitus', 'ilmakuvat', 'kuvankäsittely', 'ilmakuvaus', 'fotogrammetria', 'satelliittikuvaus', 'earth resources technology satellites.', 'spot (artificial satellite).', 'photogrammetry', 'image analysis.', 'landsat satellites.', 'monispektrinen kaukokartoitus', 'hyperspektrinen kaukokartoitus']

# %%
result = get_and_beautify_data_from_api(lookfor="SICK", year="2010")
orgs_count = count_orgs(result['records'])#for bubble chart 
subjects_count = count_subjects(result['records'])
cooccurence_with_keys = count_subjects_presented_together_one_publishcation(result['records'], subjects_count)  
cooc_matrix = cooccurence_matrix(cooccurence_with_keys)#For heatmap chart
print("Organizations: {}\nRelated subjects: {}".format(orgs_count, list(subjects_count.keys())))
# Out:
# Organizations: {'Åbo Akademis bibliotek': 1, 'Helka-kirjastot': 10, 'Aalto-yliopisto': 1, 'Centria-kirjasto': 3, 'Tritonia': 1, 'Jyväskylän yliopisto': 2, 'Varastokirjasto': 1, 'Kansalliskirjasto': 1}
# Related subjects: ['psykoser', 'psykiskt sjuka', 'anhöriga', 'psykiatrisk vård', 'psykiatriska patienter', 'psykoosit', 'psyykkisesti sairaat', 'omaiset', 'psykiatrinen hoito', 'psykiatriset potilaat', 'sick.', 'psychiatric nursing.', 'psychoses.', 'analgesics', 'back pain', 'chronic disease', 'disabled persons', 'drug utilization', 'fibromyalgia', 'insurance, disability', 'insurance, health', 'neck pain', 'occupational diseases', 'rehabilitation', 'rehabilitation, vocational', 'sick leave', 'treatment outcome', 'common cold', 'communicable disease control', 'disinfectants', 'environmental exposure', 'handwashing', 'hygiene', 'influenza, human', 'virus diseases', 'workplace', 'desinfiointiaineet', 'ennaltaehkäisy ja valvonta', 'hoidon vaikuttavuus', 'hygienia', 'influenssa', 'käsienpesu', 'nuhakuume', 'sairausloma', 'tartuntatautien ehkäisy', 'työpaikat', 'virustaudit', 'ympäristöaltistuminen', 'adult', 'aging', 'employment', 'family relations', 'health status', 'job satisfaction', 'middle aged', 'occupational health', 'pain', 'personal satisfaction', 'socioeconomic factors', 'stress, psychological', 'work', 'workload', 'esiintyvyys', 'kipu', 'kunnan työntekijät', 'psykososiaaliset tekijät', 'riskiryhmät', 'riskitekijät', 'toimintakyky', 'työkyky', 'helsinki', 'efficiency', 'human engineering', 'lifting', 'musculoskeletal diseases', 'patient education as topic', 'upper extremity', 'work capacity evaluation', 'air pollution.', 'sick building syndrome.', 'occupational health.', 'ilmanlaatu', 'sisäilma', 'terveysvaikutukset', 'terveysriskit', 'viestintä', 'vuorovaikutus', 'luottamus', 'tiedotus', 'inneluft', 'kuntoutus', 'työkyvyttömyys', 'vaikuttavuus', 'tuki- ja liikuntaelimet', 'after-hours care', 'anesthesiology', 'attitude of health personnel', 'burnout, professional', 'career mobility', 'hospital-physician relations', 'organizational culture', 'physicians', 'sex factors', 'sleep deprivation', 'social support', 'suicidal ideation', 'anestesiologit', 'työhyvinvointi', 'masennus', 'ennaltaehkäisy', 'ehkäisy', 'hoito', 'ammatillinen kuntoutus', 'työterveyshuolto', 'tuki- ja liikuntaelinten taudit', 'vajaakuntoiset', 'exercise', 'mental disorders', 'patients', 'psychiatric consultation.', 'sick', 'hospitalization', 'psychology, medical', 'referral and consultation', 'diagnoosi', 'hoitomenetelmät', 'mielenterveyshäiriöt', 'psykiatria', 'psykologia', 'sjuka hus-syndrom', 'fuktskador', 'mätmetoder', 'golv', 'sairas rakennus -oireyhtymä', 'kosteusvauriot', 'mittausmenetelmät', 'lattiat', 'aids (disease)', 'church work with the sick', 'religion', 'church work with the sick.', 'aids.', 'hiv.', 'religieuze aspecten.', 'pastoraal concilie.', 'religion / christianity / general', 'botswana.', 'great britain.', 'war', 'military medicine', 'history, 20th century', 'history, 21st century', 'great britain', 'social medicine.', 'health & fitness', 'medical', 'attitude.', 'delivery of health care.', 'pathologic processes.', 'philosophy.', 'behavior and behavior mechanisms.', 'humanities.', 'health care quality, access, and evaluation.', 'pathological conditions, signs and symptoms.', 'attitude of health personnel.', 'disease.', 'attitude to health.', 'philosophy, medical.', 'psychiatry and psychology.', 'philosophy & religion.', 'psychiatry.', 'health & biological sciences.', 'clinical psychology.', 'yhteiskunta', 'yhteiskunnallinen asema', 'terveys', 'terveydentila', 'terveydenhuolto', 'teoriat', 'yhteiskuntateoriat', 'sairaus', 'axby, johanna,', 'sjuka barn', 'lever', 'liver diseases', 'sjukdomar', 'diseases', 'sick children', 'liver', 'reaktor innovations (yhtiö)', 'sick (yhtiö)', 'accenture (yhtiö)', 'työviihtyvyys', 'työtyytyväisyys', 'yrityskulttuuri', 'työpaikkakulttuuri', 'organisaatiokulttuuri', 'työolot', 'johtaminen', 'henkilöstöjohtaminen', 'organisaatioilmasto', 'työyhteisöt', 'työilmapiiri', 'etätyö', 'työmotivaatio', 'palkitseminen', 'hyvinvointi', 'työnantajat', 'imago', 'yritykset', 'henkilöstö', 'hyvät käytännöt', 'työntekijät ...

# %%
result = get_and_beautify_data_from_api(lookfor="finnish", year="2015")
orgs_count = count_orgs(result['records'])#for bubble chart 
subjects_count = count_subjects(result['records'])
cooccurence_with_keys = count_subjects_presented_together_one_publishcation(result['records'], subjects_count)  
cooc_matrix = cooccurence_matrix(cooccurence_with_keys)#For heatmap chart
print("Organizations: {}\nRelated subjects: {}".format(orgs_count, list(subjects_count.keys())))
# Out:
# Organizations: {'Jyväskylän yliopisto': 17, 'Kansalliskirjasto': 40, 'Arcadan kirjasto': 1, 'Suomalaisen Kirjallisuuden Seura': 1, 'Svenska handelshögskolan': 2, 'Helka-kirjastot': 9, 'Itä-Suomen yliopisto': 3, 'Oulun yliopisto': 22, 'Eduskunnan kirjasto': 1, 'Aalto-yliopisto': 2, 'Centria-kirjasto': 1, 'Haaga-Helia ammattikorkeakoulu': 1}
# Related subjects: ['dyslexia', 'longitudinal', 'prediction', 'finnish', 'intervention', 'graphogame', 'l2 learning', 'length', 'duration', 'finnish parliament', 'elections', 'eduskunta', 'suomi', 'vaalit', 'code-switching', 'video games', 'english', 'immersion', 'academic myth', 'culture', 'finnish communication style', 'silence', 'elektroniikkateollisuus', 'talouspolitiikka', 'sosiaalidemokraattiset puolueet', 'opinnäytteet', 'finnish education', 'hungarian education', 'internationalization of research', 'popularization', 'self-reflection', 'learner beliefs', 'english as a foreign language', 'finnish sign language signers', 'language teaching', 'differentiation', 'finnish as a second language', 's2', 'clinical practice', 'nursing students', 'finnish language', 'finska', 'klinisk praktik', 'utländska studerande', 'lastenkirjallisuus', 'tytöt', 'emansipaatio', 'sukupuoliroolit', 'naisen asema', 'sukupuolisuus', 'arvot', 'ihanteet', 'subjekti', 'kirjallisuudentutkimus', 'finnish girls’ literature', 'emancipation', 'gender', 'ideals', 'norms', 'feminism', 'society', 'girlhood studies', "finnish girls' literature", 'church of finland', 'history of written finnish', 'early modern literature', 'mikael agricola', 'protestant reformation', 'kulttuurierot', 'ekspatriaatit', 'identiteetti', 'kulturskillnader', 'utlandsanställda', 'identitet', 'cultural differences', 'expatriates', 'identity', 'finnish professionals', 'identity construction', 'dynaaminen systeemiteoria', 'suomen kieli', 'toinen/vieras kieli', 'dynamic systems theory', 'second/foreign language', 'oppilaslähtöisyys', 'koululiikunta', 'liikunnanopetus', 'suomen cdg-malli', 'school physical education', 'student-centered teaching', 'finnish cdg model', 'formaali oppiminen', 'informaali oppiminen', 'non-formaali oppiminen', 'maahanmuuttajat', 'learning', 'non-formal learning', 'immigrants', 'dogs.', 'eläintaudit', 'fysioterapia', 'koira', 'polvet', 'raajat', 'testausmenetelmät', 'finnish canine stifle index fcsi', 'pieneläinten sairaudet', 'veterinary physiotherapy', 'kansanlingvistiikka', 'kansandialektologia', 'suomen murteet', 'raja-karjalan murteet', 'karjala', 'folk linguistics', 'perceptual dialectology', 'finnish dialects', 'the dialects of border karelia', 'karelian', 'feminismi', 'nuortenkirjallisuus', 'seksuaalisuus', 'subjekti (filosofia)', 'tyttökirjat', 'tyttötutkimus', 'finnish, second language learning', 'higher education', 'internationalisation', 'university students', 'interaction', 'kielikylpy', 'clil-opetus', 'suomi/ruotsi toisena kielenä', 'kielikasvatus', 'kieli oppimisen resurssina', 'language immersion', 'content and language integrated learning', 'finnish/swedish as a second language', 'language education', 'language as a learning resource', 'sosiaalityö', 'lastensuojelu', 'sosiaalityöntekijät', 'järjestöt', 'tukihenkilöt', 'muutos', 'vapaaehtoistyö', 'perheet', 'vanhempi-lapsisuhde', 'practice of using support persons', 'child welfare social work', 'voluntary work', 'history of the finnish child welfare', 'relational sociology', 'child-adult relations', 'academic language learning', 'multilingual and multicultural competence', 'language assessment', 'common european framework of reference', 'cefr', 'foreign workers.', 'immigrants.', 'adjustment (psychology)', 'language proficiency', 'english language', 'swedish language', 'integration', 'språkkunskap', 'utländsk arbetskraft', 'invandrare', 'engelska', 'svenska', 'integration (invandrare)', 'kielitaito', 'ulkomainen työvoima', 'englannin kieli', 'ruotsin kieli', 'kotoutuminen', 'yleisradio.', 'asenteet', 'diskurssi', 'kielenhuolto', 'kielivirheet', 'oikeakielisyys', 'paikallislehdet', 'palaute', 'radiotoimittajat', 'sanomalehdet', 'toimittajat', 'bayesian networks.', 'cost-benefit analysis.', 'decision support.', 'dispersants.', 'environmental valuation.', 'finnish archipelago sea.', 'gulf of finland.', 'maritime safety.', 'oil spill risk management.', 'probabilistic model.', 'threatened habitats.', 'th ...
